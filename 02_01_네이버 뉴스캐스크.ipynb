# %% [markdown]
# ## requests 모듈
# - 클라이언트는 서버에게 자원을 요청합니다.(request)
# - 서버는 요청받은 내용에 대해 자원을 반환합니다.(response)
# - 자원을 요청할 때(request) get을 사용해 요청합니다.

# %%
import requests
from bs4 import BeautifulSoup
url = "https://news.naver.com/"

# get 방식으로 해당 url에 request하고 response를 받아서 리턴
response = requests.get(url)
print(response)
# Out:
# <Response [200]>

# %% [markdown]
# ### request 결과 코드
# - 200: 성공
# - 404: url이 존재하지 않음
# - 400: request 문법 상의 오류
# - 401 권한에러: header 정보가 없는 경우 많이 발생
# - 402 권한에러: 자원에 대한 접근 권한 에러
# - 403 권한에러: 파일 권한, 읽기 권한 등등에 대한 에러

# %%
print(response.status_code)
# Out:
# 200

# %%
print(response.text)
# Out:
# <!doctype html>
# <html lang="ko">
# 	<head>
# 		<title id="browserTitleArea">네이버 뉴스</title>
#
#
#
# <script>
# 	function isMobileDevice() {
# 		return /^.*(iPhone|iPod|iPad|Android).*/.test(navigator.userAgent);
# 	}
# </script>
# <script>
# 	(function () {
# 		try {
# 			if (isMobileDevice() && isAbleApplyPrefersColorScheme()) {
#
# 				document.querySelector("html").classList.add("DARK_THEME");
# 			}
# 		} catch(e) {}
#
# 		function isAbleApplyPrefersColorScheme() {
#
# 			if (window.matchMedia("(prefers-color-scheme)").matches === false) {
# 				return false;
# 			}
#
# 			var userAgent = navigator.userAgent;
#
# 			if (userAgent.indexOf("NAVER") > -1) {
#
# 				if (/.*NAVER\([a-zA-Z]*;\s[a-zA-Z]*;\s([0-9]*);/.test(userAgent)) {
# 					return Number(RegExp.$1) >= 1000;
# 				}
# 			} else {
#
# 				return document.cookie.indexOf("NSCS=1") > -1;
# 			}
#
# 			return false;
# 		}
# 	})();
# </script>
#
# 		<script>
# 		var g_ssc = 'news.v3_media' || null;
# 		</script>
# 		<meta charset="utf-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no,target-densitydpi=medium-dpi"/>
# 	<link rel="stylesheet" type="text/css" href="https://ssl.pstatic.net/static.news/mnews/resources/20230112_015548/css/generated/newshome.css" />
# 			<link rel="shortcut icon" type="image/x-icon" href="https://mimgnews.pstatic.net/image/news/m/2014/favicon/favicon.ico" />
# <script>
# 	(function(){
# 		var userAgent = navigator.userAgent;
# 		var result = [];
#
# 		if(userAgent.indexOf('Android') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="96x96" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPhone') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="120X120" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_2x_120X120.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_3x_180X180.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPad') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="167x167" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPadPro_2x_167X167.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPad_2x_152X152.png" />'
# 			];
# 		}
# 		document.write(result.join('\n'));
# 	})();
# </script>
#
# <script type="text/javascript" src="https://ssl.pstatic.net/static.news/mnews/resources/20230112_015548/js/generated/statistics_jquery.js"></script>
# 	<script>
#     document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
#
#
#
# <script>
#
# document.documentElement.setAttribute('data-useragent', navigator.userAgent);
#
#
# function showNoImage(elImg, type) {
#     switch (type) {
#
#         case "remove":
#             try {
#                 elImg.parentNode.removeChild(elImg);
#             } catch(e) {}
#             break;
#
#
#         case "removeParent":
#             try {
#                 elImg.parentNode.outerHTML = '';
#             } catch(e) {}
#             break;
#
#
#         case "alt":
#             elImg.outerHTML = ('<span class="noimage_text {imgClassName}">' + (elImg.alt || "") + '</span>')
#
#                 .replace('{imgClassName}', elImg.className);
#             break;
#
#
# 		case "class" :
# 			var outerHTMLSource = Number(elImg.getAttribute("height")) > 0?
#
# 				'<span class="noimage_wrap {imgClassName}" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
# 				'<span class="noimage_wrap {imgClassName}"><span class="noimage"></span></span>';
# 			elImg.outerHTML = outerHTMLSource.replace('{imgClassName}', elImg.className);
# 			break;
#
#
#         default:
#
#             elImg.outerHTML = Number(elImg.getAttribute("height")) > 0?
#
#                 '<span class="noimage_wrap" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
#                 '<span class="noimage_wrap"><span class="noimage"></span></span>';
#     }
# }
#
#
# function doAfterLoadEnd(callback, callbackOnPersisted) {
#     var eventName = "onpageshow" in window ? "pageshow" : "load";
#
#     callback = callback || function(){};
#     callbackOnPersisted = callbackOnPersisted || function(){};
#
#     window.addEventListener(eventName, function(e) {
#         try{
#             if(Boolean(e.persisted)){
#                 callbackOnPersisted();
#                 return;
#             }
#         }catch(e){}
#
#         callback();
#     });
# }
# </script>
# 		<meta property="og:title"			content="네이버 뉴스"/>
#   <meta property="og:type"			content="website"/>
#   <meta property="og:url"			content="https://news.naver.com/main/home.naver"/>
#   <meta property="og:image"			content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png"/>
#   <meta property="og:description"	content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공"/>
#   <meta property="og:article:author" content="네이버">
#   <meta name="twitter:card"			content="summary">
#   <meta name="twitter:title"		content="네이버 뉴스">
#   <meta name="twitter:site"			content="네이버 뉴스">
#   <meta name="twitter:creator"		content="네이버 뉴스">
#   <meta name="twitter:image"		content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png">
#   <meta name="twitter:description"	content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공">
#
#
#         <script>
#
#     (function () {
#         var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#         if (!isUnderIE10) {
#             var script = document.createElement("script");
#             script.async = true;
#             script.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#             document.head.appendChild(script);
#         }
#     })();
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#     window.gladsdk.cmd.push(function () {
#
#         window.gladsdk.setGlobalConfig({
#             enablePersistAd: true
#         });
#
#
#         var adUnits = [];
#
#         adUnits.push({
#             adUnitId: "p_news_sidebox",
#             adSlotElementId: "glad_ad_sidebox",
#             customParam: {
#                 calp: "home"
#             }
#         });
#
#         for (let i = 0; i < adUnits.length; i++) {
#             window.gladsdk.defineAdSlot(adUnits[i]);
#         }
#
#
#         var htmlClass = document.querySelector("html").getAttribute("class");
#         if (htmlClass && htmlClass.indexOf("DARK_THEME") > -1) {
#             window.gladsdk.setHostMeta("theme", "system");
#         }
#     });
# </script>
#
#
#
# 	</head>
#
# 	<body class=" as_mp_layout">
# 		<div class="u_skip"><a href="#ct">본문 바로가기</a></div>
#
# <!-- Menu 구분  -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <section class="news_header">
#     <header class="nh_header" role="banner">
#         <div class="Ngnb">
#             <div class="Ngnb_inner">
#                 <div class="Ngnb_both">
#                     <div class="Ngnb_left">
#                         <span class="Ngnb_logo"><a href="https://www.naver.com" onclick="nclk(event,'gnb.naver','','');" class="Nlogo_link"><span class="Nicon_logo">NAVER</span></a></span>
#                         <div class="Ngnb_service">
#                             <h1 class="Nservice_item"><a href="https://news.naver.com" onclick="nclk(event,'gnb.news','','');"><span class="Nicon_service">뉴스</span></a></h1>
#                             <span class="Nservice_subitem">
#                                 <a href="https://entertain.naver.com/home" onclick="nclk(event,'gnb.enter','','');">
#                                     <span class="Nicon_family Nicon_entertain">연예</span>
#                                 </a>
#                             </span>
#                             <span class="Nservice_subitem">
#                                 <a href="https://sports.news.naver.com/index" onclick="nclk(event,'gnb.sports','','');">
#                                     <span class="Nicon_family Nicon_sports">스포츠</span>
#                                 </a>
#                             </span>
#                             <span class="Nservice_subitem">
# 								<a href="https://weather.naver.com/" onclick="nclk(event,'gnb.weather','','');">
# 									<span class="Nicon_family Nicon_weather">날씨</span>
# 								</a>
# 							</span>
#                             <span class="Nservice_subitem">
# 								<a href="https://contents.premium.naver.com/" onclick="nclk(event,'gnb.premium','','');">
# 									<span class="Nicon_family Nicon_premium">프리미엄</span>
# 								</a>
# 							</span>
#                         </div>
#                     </div>
#
# <div class="Ngnb_right">
#     <div class="Ngnb_group">
#         <div id="gnb" class="gnb_dark_type2"></div>
#     </div>
#
#     <div class="Ngnb_search is_hidden _search_content"></div>
#     <div class="Ngnb_tool">
#         <a href="javascript:;"
#            class="Ntool_button _search_content_toggle_btn"
#            onclick="nclk(event,'gnb.sch','','');"><span class="Nicon_search">검색</span></a>
#     </div>
# </div>
#
#                 </div>
#             </div>
#         </div>
#
#         <div class="Nlnb _float_lnb">
#             <div class="Nlnb_inner">
#                 <div class="Nlnb_both">
#                     <div class="Nlnb_left _lnb_scroll">
#                         <div class="Nlnb_menu Ntype_scroll">
#                             <div class="Nlnb_menu_inner _scroll">
#                                 <ul class="Nlnb_menu_list" role="menu">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item is_active"><a href="https://news.naver.com/?viewType=pc" class="Nitem_link" role="menuitem" aria-selected="true" onclick="nclk(event,'lnb.pcmedia','','');"><span class="Nitem_link_menu">언론사별</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item"><a href="https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=100" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.pol','','');"><span class="Nitem_link_menu">정치</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item"><a href="https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=101" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.eco','','');"><span class="Nitem_link_menu">경제</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item"><a href="https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=102" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.soc','','');"><span class="Nitem_link_menu">사회</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item"><a href="https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=103" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.lif','','');"><span class="Nitem_link_menu">생활/문화</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item"><a href="https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=105" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.sci','','');"><span class="Nitem_link_menu">IT/과학</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item"><a href="https://news.naver.com/main/main.naver?mode=LSD&mid=shm&sid1=104" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.wor','','');"><span class="Nitem_link_menu">세계</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item _isNew"><a href="https://news.naver.com/main/ranking/popularDay.naver" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.rank','','');"><span class="Nitem_link_menu">랭킹</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item _isNew"><a href="https://news.naver.com/newspaper/home?viewType=pc" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.paper','','');"><span class="Nitem_link_menu">신문보기</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item"><a href="https://news.naver.com/opinion/home" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.opi','','');"><span class="Nitem_link_menu">오피니언</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item"><a href="https://news.naver.com/main/tv/index.naver?mid=tvh" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.tv','','');"><span class="Nitem_link_menu">TV</span></a></li>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         <li class="Nlist_item"><a href="https://news.naver.com/main/factcheck/main.naver" class="Nitem_link" role="menuitem" aria-selected="false" onclick="nclk(event,'lnb.fact','','');"><span class="Nitem_link_menu">팩트체크</span></a></li>
#
#                                 </ul>
#                             </div>
#                         </div>
#                     </div>
#                     <div class="Nlnb_right">
#                         <div id="" class="lnb_extra">
#                             <div class="lnb_extra_menu">
#                                 <ul class="lnb_extra_menu_list">
#                                     <li class="lnb_extra_menu_item"><a href="https://news.naver.com/main/officeList.naver" class="lnb_extra_menu_link" onclick="nclk(event,'slb.allmedia','','');">전체 언론사</a></li>
#                                     <li class="lnb_extra_menu_item"><a href="https://newsstand.naver.com/" class="lnb_extra_menu_link" target="_blank" onclick="nclk(event,'slb.newsstand','','');">뉴스스탠드</a></li>
#                                     <li class="lnb_extra_menu_item"><a href="https://newslibrary.naver.com/search/searchByDate.naver" class="lnb_extra_menu_link" target="_blank" onclick="nclk(event,'slb.library','','');">라이브러리</a></li>
#                                 </ul>
#                             </div>
#                         </div>
#                     </div>
#                 </div>
#             </div>
#         </div>
#     </header>
# </section>
# <hr />
# 		<div id="ct" role="main" class="main_wrap">
#
#
# <div class="main_container">
#     <section class="main_content">
#         <h3 class="blind">콘텐츠</h3>
#
#
# <div class="main_sublnb">
#     <div class="main_sublnb_date">
#         <strong>1</strong>.<strong>16</strong><span>(월)</span>
#     </div>
#     <ul class="main_sublnb_menu">
#         <li class="main_sublnb_item"><a href="https://news.naver.com/main/officeList.naver " class="main_sublnb_link" onclick="nclk(event, 'slb.allmedia', '', '')">전체 언론사</a></li>
#         <li class="main_sublnb_item"><a href="https://newsstand.naver.com/" class="main_sublnb_link" target="_blank" onclick="nclk(event, 'slb.newsstand', '', '')">뉴스스탠드</a></li>
#         <li class="main_sublnb_item"><a href="https://newslibrary.naver.com/search/searchByDate.naver" class="main_sublnb_link" target="_blank" onclick="nclk(event, 'slb.library', '', '')">라이브러리</a></li>
#     </ul>
# </div>
#
#         <div class="main_brick">
#             <!-- BRICK HOUSE -->
#             <div class="grid1_wrap brick-house _brick_gid_wrapper">
#                 <div class="brick-vowel _brick_column">
#
#
#
#
#
# <div class="main_brick_item _press_main_status_wrapper">
#     <div class="comp_journal_subscribe">
#         <div class="cjs_title_wrap">
#             <h3 class="cjs_edit_title">
#                 <span class="cjs_main">언론사편집</span>
#                 <a href="#feedCard" class="cjs_subscribe_a" onclick="nclk(event, 'home.editassetting', '', '')">
#                     <span class="subs_text">기자
#
#                     </span>
#                     <span class="subs_text">연재
#
#                     </span>
#                 </a>
#             </h3>
#             <a href="https://media.naver.com/channel/settings" class="cjs_more_link" onclick="nclk(event, 'home.editsetting', '', '')">
#                 구독설정
#
#                 <span class="ico_more"></span>
#             </a>
#         </div>
#
#     </div>
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="main_brick_item _channel_news_preview_wrapper" data-max-page="16">
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="comp_journal_subscribe _preview_card_page" style="">
#     <div class="cjs_channel_card">
#
#
#
#
#                 <div class="cjs_ctitle _item_title">
#                     <a href="https://media.naver.com/press/003" class="cjs_ctitle_a" onclick="nclk(event, 'home.editnfmedia', '', '')">
#                         <div class="cjs_cmw small">
#                             <img
#                                     loading='lazy'
#                                 src="https://mimgnews.pstatic.net/image/upload/office_logo/003/2022/02/21/logo_003_56_20220221152351.jpg?type=nf76_76_q90" width="28" height="28" onerror="showNoImage(this)">
#                         </div>
#                         <div class="cjs_ctw">
#                             <h4 class="channel">뉴시스<span class="datetime">01월 16일 18:29</span></h4>
#                         </div>
#                     </a>
#                     <div class="cjs_ctitle_right">
#                         <button type="button" class="cjs_btn_subscribe _subscribe_btn"
#                                 data-office_id="003"
#                                 data-office_name="뉴시스"
#                                 onclick="nclk(event, 'home.editnfset', '', '')">구독</button>
#                     </div>
#                 </div>
#                 <div class="cjs_journal_wrap _item_contents">
#
#
#                     <a href="https://n.news.naver.com/article/003/0011645704" class="cjs_news_a _cds_link _editn_link" onclick="nclk(event, 'home.editnfimg', '', '')">
#                         <div class="cjs_news_mw">
#                             <img
#                                     loading='lazy'
#                                 src="https://mimgnews.pstatic.net/image/origin/003/2023/01/16/11645704.jpg?type=nf264_176&ut=20230116165913" width="100%" alt="" onerror="showNoImage(this)">
#
#                         </div>
#                         <div class="cjs_news_tw">
#
#
#
#                                     <div class="cjs_t">기체 90도 기울며 추락…네팔 민항기 마지막 순간(영상)</div>
#
#
#
#                                             <p class="cjs_d">네팔의 포카라 신공항 인근에서 추락해 최소 68명이 사망한 민항기의 추락 전후 상황이 담긴 영상이 온라인에서 퍼지고 있다. 15일(현지시간) CNN·데일리메일 등에 따르면 이날 오전 72명이 탄 민항기는 네팔 수도 </p>
#
#
#
#
#                         </div>
#                     </a>
#                 </div>
#
#
#
#
#
#                 <div class="cjs_ctitle _item_title">
#                     <a href="https://media.naver.com/press/087" class="cjs_ctitle_a" onclick="nclk(event, 'home.editnfmedia', '', '')">
#                         <div class="cjs_cmw small">
#                             <img
#                                     loading='lazy'
#                                 src="https://mimgnews.pstatic.net/image/upload/office_logo/087/2019/08/22/logo_087_56_20190822110222.png?type=nf76_76_q90" width="28" height="28" onerror="showNoImage(this)">
#                         </div>
#                         <div class="cjs_ctw">
#                             <h4 class="channel">강원일보<span class="datetime">01월 16일 19:03</span></h4>
#                         </div>
#                     </a>
#                     <div class="cjs_ctitle_right">
#                         <button type="button" class="cjs_btn_subscribe _subscribe_btn"
#                                 data-office_id="087"
#                                 data-office_name="강원일보"
#                                 onclick="nclk(event, 'home.editnfset', '', '')">구독</button>
#                     </div>
#                 </div>
#                 <div class="cjs_journal_wrap _item_contents">
#
#
#                     <a href="https://n.news.naver.com/article/087/0000947253" class="cjs_news_a _cds_link _editn_link" onclick="nclk(event, 'home.editnfimg', '', '')">
#                         <div class="cjs_news_mw">
#                             <img
#                                     loading='lazy'
#                                 src="https://mimgnews.pstatic.net/image/origin/087/2023/01/16/947253.jpg?type=nf264_176&ut=20230116183403" width="100%" alt="" onerror="showNoImage(this)">
#
#                         </div>
#                         <div class="cjs_news_tw">
#
#
#
#                                     <div class="cjs_t">한동훈, '이재명 만난 적 없다' 김성태에 "일종의 말맞추기 신호...그런다고 범죄 수사가 안 되지 않아"</div>
#
#
#
#                                             <p class="cjs_d">한동훈 법무부 장관은 16일 김성태 전 쌍방울그룹 회장이 국내 송환을 앞두고 언론 인터뷰에서 더불어민주당 이재명 대표를 만난 적이 없다고 주장한 것에 대해 &#034;해외 도피한 중범죄자들이 못 견디고 귀국하기 직전에 자기 </p>
#
#
#
#
#                         </div>
#                     </a>
#                 </div>
#
#
#
#
#
#                 <div class="cjs_ctitle _item_title">
#                     <a href="https://media.naver.com/press/094" class="cjs_ctitle_a" onclick="nclk(event, 'home.editnfmedia', '', '')">
#                         <div class="cjs_cmw small">
#                             <img
#                                     loading='lazy'
#                                 src="https://mimgnews.pstatic.net/image/upload/office_logo/094/2018/09/20/logo_094_56_20180920153620.png?type=nf76_76_q90" width="28" height="28" onerror="showNoImage(this)">
#                         </div>
#                         <div class="cjs_ctw">
#                             <h4 class="channel">월간산<span class="datetime">01월 16일 09:17</span></h4>
#                         </div>
#                     </a>
#                     <div class="cjs_ctitle_right">
#                         <button type="button" class="cjs_btn_subscribe _subscribe_btn"
#                                 data-office_id="094"
#                                 data-office_name="월간산"
#                                 onclick="nclk(event, 'home.editnfset', '', '')">구독</button>
#                     </div>
#                 </div>
#                 <div class="cjs_journal_wrap _item_contents">
#
#
#                     <a href="https://n.news.naver.com/article/094/0000010623" class="cjs_news_a _cds_link _editn_link" onclick="nclk(event, 'home.editnfimg', '', '')">
#                         <div class="cjs_news_mw">
#                             <img
#                                     loading='lazy'
#                                 src="https://mimgnews.pstatic.net/image/origin/094/2023/01/16/10623.jpg?type=nf264_176&ut=20230116070101" width="100%" alt="" onerror="showNoImage(this)">
#
#                         </div>
#                         <div class="cjs_news_tw">
#
#
#
#                                     <div class="cjs_t">[거칠부 다이어리] 안나푸르나에서 닭 백숙을 삶다</div>
#
#
#
#                                             <p class="cjs_d">네팔 히말라야에서 안나푸르나만큼 자동차가 깊숙이 들어오는 곳도 없지 싶다. 고소적응에 문제 되지 않는다면, 카트만두에서 마낭Manang(3,540m)까지 이틀이면 갈 수 있다. 사실 처음 안나푸르나에서 걸을 때 가장</p>
#
#
#
#
#                         </div>
#                     </a>
#                 </div>
#
#
#
#
#
#                 <div class="cjs_ctitle _item_title">
#                     <a href="https://media.naver.com/press/666" class="cjs_ctitle_a" onclick="nclk(event, 'home.editnfmedia', '', '')">
#                         <div class="cjs_cmw small">
#                             <img
#                                     loading='lazy'
#                                 src="https://mimgnews.pstatic.net/image/upload/office_logo/666/2023/01/03/logo_666_56_20230103174615.png?type=nf76_76_q90" width="28" height="28" onerror="showNoImage(this)">
#                         </div>
#                         <div class="cjs_ctw">
#                             <h4 class="channel">경기일보<span class="datetime">01월 16일 18:17</span></h4>
#                         </div>
#                     </a>
#                     <div class="cjs_ctitle_right">
#                         <button type="button" class="cjs_btn_subscribe _subscribe_btn"
#                                 data-office_id="666"
#                                 data-office_name="경기일보"
#                                 onclick="nclk(event, 'home.editnfset', '', '')">구독</button>
#                     </div>
#                 </div>
#                 <div class="cjs_journal_wrap _item_contents">
#
#
#                     <a href="https://n.news.naver.com/article/666/0000001656" class="cjs_news_a _cds_link _editn_link" onclick="nclk(event, 'home.editnfimg', '', '')">
#                         <div class="cjs_news_mw">
#                             <img
#                                     loading='lazy'
#                                 src="https://mimgnews.pstatic.net/image/origin/666/2023/01/16/1656.jpg?type=nf264_176&ut=20230116163604" width="100%" alt="" onerror="showNoImage(this)">
#
#                         </div>
#                         <div class="cjs_news_tw">
#
#
#
#                                     <div class="cjs_t">'한파도 좋아' 제철 맞은 가평 어비계곡 빙벽 [포토뉴스]</div>
#
#
#
#                                             <p class="cjs_d">경기 동부지역에 한파주의보가 발령된 16일 오후 가평군 어비산 어비계곡 빙벽을 찾은 시민들이 추위에 아랑곳하지 않고 겨울 정취를 만끽하고 있다.</p>
#
#
#
#
#                         </div>
#                     </a>
#                 </div>
#
#
#
#
#
#                 <div class="cjs_ctitle _item_title">
#                     <a href="https://media.naver.com/press/277" class="cjs_ctitle_a" onclick="nclk(event, 'home.editnfmedia', '', '')">
#                         <div class="cjs_cmw small">
#                             <img
#                                     loading='lazy'
#                                 src="https://mimgnews.pstatic.net/image/upload/office_logo/277/2018/07/18/logo_277_56_20180718153218.png?type=nf76_76_q90" width="28" height="28" onerror="showNoImage(this)">
#                         </div>
#                         <div class="cjs_ctw">
#                             <h4 class="channel">아시아경제<span class="datetime">01월 16일 19:15</span></h4>
#                         </div>
#                     </a>
#                     <div class="cjs_ctitle_right">
#                         <button type="button" class="cjs_btn_subscribe _subscribe_btn"
#                                 data-office_id="277"
#                                 data-office_name="아시아경제"
#                                 onclick="nclk(event, 'home.editnfset', '', '')">구독</button>
#                     </div>
#                 </div>
#                 <div class="cjs_journal_wrap _item_contents">
#
#
#                     <a href="https://n.news.naver.com/article/277/0005205837" class="cjs_news_a _cds_link _editn_link" onclick="nclk(event, 'home.editnfimg', '', '')">
#                         <div class="cjs_news_mw">
#                             <img
#                                     loading='lazy'
#                                 src="https://mimgnews.pstatic.net/image/origin/277/2023/01/16/5205837.jpg?type=nf264_176&ut=20230116165501" width="100%" alt="" onerror="showNoImage(this)">
#
#                         </div>
#                         <div class="cjs_news_tw">
#
#
#
#                                     <div class="cjs_t">또 이 가방 들었네…김건희 여사 '19만원 친환경 백'</div>
#
#
#
#                                             <p class="cjs_d">윤석열 대통령이 김건희 여사와 함께 아랍에미리트(UAE), 스위스 6박 8일 순방길에 오른 가운데 김 여사의 가방에 대한 관심이 높아지고 있다. 김 여사는 아부다비에 도착해 공군 1호기에서 내릴 때 옷은 갈아입었으나</p>
#
#
#
#
#                         </div>
#                     </a>
#                 </div>
#
#
#         <div class="cjs_info">
#             <button type="button" class="cjs_btn_refresh _refresh_btn" card_type="preview" size="5" data-page="0" data-max-page="" onclick="nclk(event, 'home.editnfnew', '', '')">새로보기</button>
#         </div>
#     </div>
# </div>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <div class="comp_journal_subscribe _preview_card_page" style="display:none">
#     <div class="cjs_channel_card">
#
#
#
#
#                 <div class="cjs_ctitle _item_title">
#                     <a href="https://media.naver.com/press/665" class="cjs_ctitle_a" onclick="nclk(event, 'home.editnfmedia', '', '')">
#                         <div class="cjs_cmw small">
#                             <img
#                                     loading='lazy'
#                                 data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/665/2022/12/08/logo_665_56_20221208184224.png?type=nf76_76_q90" width="28" height="28" onerror="showNoImage(this)">
#                         </div>
#                         <div class="cjs_ctw">
#                             <h4 class="channel">더스쿠프<span class="datetime">01월 16일 14:54</span></h4>
#                         </div>
#                     </a>
#                     <div class="cjs_ctitle_right">
#                         <button type="button" class="cjs_btn_subscribe _subscribe_btn"
#                                 data-office_id="665"
#                                 data-office_name="더스쿠프"
#                                 onclick="nclk(event, 'home.editnfset', '', '')">구독</button>
#                     </div>
#                 </div>
#                 <div class="cjs_journal_wrap _item_contents">
#
#
#                     <a href="https://n.news.naver.com/article/665/0000000310" class="cjs_news_a _cds_link _editn_link" onclick="nclk(event, 'home.editnfimg', '', '')">
#                         <div class="cjs_news_mw">
#                             <img
#                                     loading='lazy'
#                                 data-onshow-src="https://mimgnews.pstatic.net/image/origin/665/2023/01/16/310.jpg?type=nf264_176&ut=20230116145201" width="100%" alt="" onerror="showNoImage(this)">
#
#                         </div>
#                         <div class="cjs_news_tw">
#
#
#
#                                     <div class="cjs_t">"기준 강화해 층간소음 잡겠다?" 탁상공론과 뼈아픈 현실</div>
#
#
#
#                                             <p class="cjs_d">&#034;층간소음 기준을 강화했다. 이로 인해 &#039;층간소음 성가심&#039; 정도는 기존의 절반 수준으로 낮아질 것이다. 층간소음 분쟁에서 피해자가 피해를 인정받을 가능성도 높아졌다.&#034; 지난해 12월 30일 환경부와 국토교통부가 &#039;공</p>
#
#
#
#
#                         </div>
#                     </a>
#                 </div>
#
#
#
#
#
#                 <div class="cjs_ctitle _item_title">
#                     <a href="https://media.naver.com/press/127" class="cjs_ctitle_a" onclick="nclk(event, 'home.editnfmedia', '', '')">
#                         <div class="cjs_cmw small">
#                             <img
#                                     loading='lazy'
#                                 data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/127/2020/04/02/logo_127_56_20200402162102.png?type=nf76_76_q90" width="28" height="28" onerror="showNoImage(this)">
#                         </div>
#                         <div class="cjs_ctw">
#                             <h4 class="channel">기자협회보<span class="datetime">01월 14일 22:28</span></h4>
#                         </div>
#                     </a>
#                     <div class="cjs_ctitle_right">
#                         <button type="button" class="cjs_btn_subscribe _subscribe_btn"
#                                 data-office_id="127"
#                                 data-office_name="기자협회보"
#                                 onclick="nclk(event, 'home.editnfset', '', '')">구독</button>
#                     </div>
#                 </div>
#                 <div class="cjs_journal_wrap _item_contents">
#
#
#                     <a href="https://n.news.naver.com/article/127/0000033569" class="cjs_news_a _cds_link _editn_link" onclick="nclk(event, 'home.editnfimg', '', '')">
#                         <div class="cjs_news_mw">
#                             <img
#                                     loading='lazy'
#                                 data-onshow-src="https://mimgnews.pstatic.net/image/origin/127/2023/01/13/33569.jpg?type=nf264_176&ut=20230113101201" width="100%" alt="" onerror="showNoImage(this)">
# ...
#                                 </div>
#
#                             <div class="css_stw">
#                                 <h4 class="css_series_title">
#                                     <span class="css_stitle">
#                                         6세 초등생이 교실에서 총격을...미국선 처음 아니었다[특파원 24시]
#                                     </span>
#                                 </h4>
#                                 <a href="https://news.naver.com/main/hotissue/sectionList.naver?mid=hot&sid1=110&cid=1085867"
#                                    class="css_series _cds_link"
#                                    onclick="nclk(event, 'home.editseries', '', '')">
#                                         <div class="css_sthumb"><img
#                                                 loading='lazy'
#                                                 data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/469/2017/01/05/logo_469_18_20170105111205.png?type=nf40_40" width="20" height="20" alt="" onerror="showNoImage(this)"></div>
#
#
#                                              <div class="css_sname">특파원 24시</div>
#
#                                 </a>
#                                 <div class="css_state_wrap _subscribe_wrapper">
#
#
#
#                                             <span class="css_state _is_subscribe" style="display: none">구독중</span>
#                                             <button type="button" class="css_btn_subscribe _subscribe_btn"
#                                                     data-channel_key="HS_1085867"
#                                                     data-channel_group="HOT_SERIES"
#                                                     data-channel_name="특파원 24시"
#                                                     onclick="nclk(event, 'home.editstake', '', '')">구독</button>
#
#
#                                 </div>
#                             </div>
#                             <a href="https://n.news.naver.com/mnews/hotissue/article/469/0000718406?cid=1085867"
#                                class="css_series_a _cds_link"
#                                onclick="nclk(event, 'home.editseriescont', '', '')">
#                                 <span class="blind">특파원 24시</span>
#                             </a>
#                         </div>
#                     </li>
#
#             </ul>
#
#                 <div class="css_info">
#                     <button type="button" class="css_btn_refresh _refresh_btn" onclick="nclk(event, 'home.editsnmore', '', '')"></button>
#                 </div>
#
#         </div>
#     </div>
# </div>
#
#
#                 </div>
#                 <div class="brick-vowel _brick_column">
#
#                 </div>
#                 <div class="brick-vowel _brick_column">
#                 </div>
#             </div>
#         </div>
#
#     </section>
#     <section class="main_aside _aside_wrapper">
#         <div class="main_aside_inner _aside_content">
#             <h3 class="blind">구독</h3>
#             <div class="_aside"></div>
# <script>
# doAfterLoadEnd(loadAside);
#
#
# function loadAside() {
#     var forcePcVersion = "";
#
#     if (isMobileDevice() && !forcePcVersion) {
#         return;
#     }
#     var iframe = append();
#     var asideFixed;
#
#     window.addEventListener('message', function(event) {
#         var data = event.data;
#
#         if (event.origin !== "https://news.naver.com") {
#             return;
#         }
#
#         if (data.type === "setIframeSize" && data.height) {
#             iframe.style.height = data.height + 'px';
#             iframe.style.visibility = "";
#
#             try {
#                 asideFixed.deactivate(); // event 중복 적용되지 않게
#             } catch(e) {}
#
#             asideFixed = AsideFixed({
#                 "wrapper" : document.querySelector("._aside_wrapper")
#
#             });
#         }
#     });
#
#
#     function append() {
#         var iframe = document.createElement('iframe');
#
#         iframe.width = "100%";
#         iframe.height = "0";
#         iframe.style.visibility = "hidden";
#         iframe.setAttribute("frameborder", "no");
#         iframe.setAttribute("scrolling", "no");
#         iframe.src = "https://news.naver.com/aside?oid=";
#
#         document.querySelector("._aside").appendChild(iframe);
#
#         return iframe;
#     }
# }
# </script>
#         </div>
#     </section>
#
#     <div class="layer_toast" style="display: none"></div>
#     <div class="layer_toast_journal_subscribe _subscribe_toast_layer" style="display: none">
#         <button type="button" class="lt_btn_set _subscribe_toast_btn" onclick="nclk(event, 'home.edittallchk', '', '')"></button>
#     </div>
# </div>
#
# 		</div>
#
# </div>
#
# <!-- //ct -->
#
#
#
#
#
#
# <hr />
#
#
#
#
#
#
#
#
#
# <div class="mp_footer">
#
#
#
#     <div class="f_subinfo">
#         <div class="f_subinfoinner">
#             <div class="f_notice">
#                 <h5 class="f_notice_badge">공지</h5>
#                 <a href="https://m.news.naver.com/ombudsman/noticeread?notiId=707" data-mpurl='{"m":"https://m.news.naver.com/ombudsman/noticeread?notiId=707","p":"https://news.naver.com/main/ombudsman/readView.naver?notiId=707"}' class="f_notice_link" onclick="nclk(event, 'fot.noticetext', '', '');">
#                     <p class="f_notice_text">위클리 심층 키워드 출시 안내</p>
#                 </a>
#             </div>
#         </div>
#     </div>
#
#     <div class="f_maininfo">
#         <div class="f_maininfoinner">
#             <a href="javascript:;" class="r_pg_top _go_top" id="goTop" onclick="nclk(event, 'fot.pctop', '', '');">맨위로</a>
#
#             <footer role="contentinfo">
#                 <p id="u_ftlkw" class="u_ftlkw _footer_login">
#                     <a href="https://m.naver.com/services.html"  data-mpurl='{"m":"https://m.naver.com/services.html","p":"https://www.naver.com/more.html"}' class="u_ftlk" onclick="nclk(event,'fot.serviceall','','');">전체서비스</a>
#                 </p>
#                 <p class="u_cr">
#                     <span class="u_ftm">
#
#
#
#                     <span class="u_cri u_cri_v1"><a href="https://policy.naver.com/policy-mobile/term.html?type=1?type=1" data-mpurl='{"m":"https://policy.naver.com/policy-mobile/term.html?type=1?type=1","p":"https://policy.naver.com/rules/service.html"}' class="u_cra" onclick="nclk(event,'fot.agreement','','');">이용약관</a></span>
#                     <span class="u_cri u_cri_v1"><a href="https://policy.naver.com/policy-mobile/privacy.html" data-mpurl='{"m":"https://policy.naver.com/policy-mobile/privacy.html","p":"https://policy.naver.com/rules/privacy.html"}' class="u_cra" onclick="nclk(event,'fot.privacy','','');"><strong>개인정보처리방침</strong></a></span>
#                     <span class="u_cri u_cri_v1">청소년 보호 책임자 : 이희만</span>
#                     <span class="u_cri u_cri_v1"><a href="https://m.news.naver.com/ombudsman/index" data-mpurl='{"m":"https://m.news.naver.com/ombudsman/index","p":"https://news.naver.com/main/ombudsman/index.naver"}' class="u_cra" onclick="nclk(event,'fot.guide','','');">서비스안내</a></span>
#
#
# 					</span>
#
#
#
#                     <span class="u_cri">각 언론사가 직접 콘텐츠를 편집합니다.</span>
#
#
#                 </p>
#             </footer>
#         </div>
#     </div>
# </div>
#
#
#
#
#
#
#
#
#
# 				<script type="text/javascript" src="https://ssl.pstatic.net/static.news/mnews/resources/20230112_015548/js/generated/news.mobile.js"></script>
#
# 				<script type="text/javascript" src="https://ssl.pstatic.net/static.news/mnews/resources/20230112_015548/js/generated/pressmain.dependency.js"></script>
#
#
#
#
# 		<script type="text/javascript">
# /**
#  * 이 파일은 모바일 뉴스 서비스 전체 페이지에 적용되는 스크립트로써,
#  * 코드 추가 시 Front-End 성능 관점에서 주의를 요합니다.
#  */
# jQuery(window).on('load', function(){
#     setTimeout(onload, 10);
#
#     function onload(){
#         var oLnb = new news.Lnb('._lnb_scroll');
#         new news.ImageLazyLoader().load("img[data-src]");
#         new news.MoveTopButton("._go_top");
#
#
#         new news.HistoryManager().init("naver_mobile_news_history", "");
#
#         // iframe lazy-loading
#         (function(){
#             try {
#                 Array.prototype.slice.apply(document.querySelectorAll('iframe[data-src]'))
#                     .forEach(function(iframeEl) {
#                         var originSrc = iframeEl.getAttribute('data-src');
#                         if(originSrc) {
#                             iframeEl.setAttribute('src', originSrc);
#                         }
#                     });
#             }catch(e) {}
#         })();
#
#         if(typeof init === "function"){
#             init();
#         }
#
#         var cookie = news.Cookie.getInstance();
#         var isShownNewLnb = cookie.getItem("isShownNewLnb");
#         if(isShownNewLnb == null) {
#             isShownNewLnb = "Y";
#             cookie.setItem("isShownNewLnb", isShownNewLnb, 3650, "", "/");
#             $("._isNew").addClass("is_new");
#         }
#
#         {
#             var footerLogin = jQuery(document).find('._footer_login');
#             if(footerLogin <= 0) {
#                 return;
#             }
#
#             // 디바이스에 따라 로그인, 로그아웃 URL 분기
#             var loginUrl = "https://nid.naver.com/nidlogin.login";
#             var logoutUrl = "https://nid.naver.com/nidlogin.logout?";
#             if (news.Util.getAgentInfo().bMobileOrTablet) {
#                 loginUrl = "https://nid.naver.com/nidlogin.login?svctype=262144";
#                 logoutUrl = "https://nid.naver.com/nidlogin.logout?svctype=262144&";
#             }
#
#             if(news.LoginAssistor.isLoginUser()) {
#                 footerLogin.prepend('<a href="javascript:news.Util.logout(\''+logoutUrl+'url=\'+encodeURIComponent(location.href));" class="u_ftlk" id="news_logout" onclick="nclk(event,\'fot.logout\',\'\',\'\');" >로그아웃</a>')
#             }else {
#                 footerLogin.prepend('<a href="'+loginUrl+'" class="u_ftlk" id="news_login" onclick="nclk(event,\'fot.login\',\'\',\'\');" >로그인</a>')
#             }
#         }
#     }
# });
# </script>
#
#
#
#
#
#
#
#
#
#
#
#
#
# <script id="feedRefreshButtonTemplate" type="text/x-handlebars-template">
#     새로보기
#     <span class="paging">
#         <span class="blind">현재</span>{{currentPage}}
#         <em class="total"> / <span class="blind">전체</span>{{totalPage}}</em>
#     </span>
# </script>
# <script type="text/javascript">
#     BrickGridForEditByPress($("._brick_gid_wrapper"));
#     PressMainStatusCard($('._press_main_status_wrapper'));
#     NewsFlashCard($('._newsflash_wrapper'));
#     FeedCard($('._journalist_feed_card_wrapper'), 'journalist', 'https://m.news.naver.com');
#     FeedCard($('._series_feed_card_wrapper'), 'series', 'https://m.news.naver.com');
#
#
#
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#         adSlot.setCustomParam("calp", 'home');
#         window.gladsdk.displayAd(adSlot);
#
#
#         window.gladsdk.addEventListener(window.gladsdk.event.ERROR, function (ad, error) {
#             $("._card_ad").hide();
#         });
#     });
#
#     $('._channel_news_card_wrapper').each(function () {
#         var wrapper = $(this);
#         ChannelNewsCard(wrapper, 'https://m.news.naver.com');
#     })
#
#     ChannelNewsPreviewCard($('._channel_news_preview_wrapper'), 'https://m.news.naver.com');
#     SubscribeBannerShortCard($('._short_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#     SubscribeBannerLongCard($('._long_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#
#     WeeklySpecialReportCard($('._weekly_special_report_card_wrapper'));
#
#     $('._horizontal_card_wrapper').each(function () {
#         var wrapper = $(this);
#         HorizontalTypeCard(wrapper, 'https://m.news.naver.com');
#     });
#
#     SpecialReportCard($('._special_report_card_wrapper'), 'https://m.news.naver.com');
#
#     ArticleLinkParamsAppender('news_media_pc');
#
#
#     (function () {
#       var seriesFeedCard = $('._series_feed_card_wrapper');
#       var seriesOffset = getOffset(seriesFeedCard);
#       var journalistFeedCard = $('._journalist_feed_card_wrapper');
#       var journalistOffset = getOffset(journalistFeedCard);
#       var targetCard = seriesOffset > journalistOffset ? journalistFeedCard : seriesFeedCard;
#       targetCard.find('._feed_card_anchor').attr('id', 'feedCard');
#
#       function getOffset (target) {
#         if (target[0]) {
#           return  target.offset().top;
#         }
#         return Number.MAX_VALUE;
#       }
#     })();
# </script>
#
#
#
# 		<script>
#     var gnb_service = 'news';
#     var gnb_logout = encodeURIComponent(location.href);
#     var gnb_template = 'gnb_utf8';
#     var gnb_brightness = 3;
#
#     doAfterLoadEnd(function () {
#         try {
#             GlobalMPUrlManager.init();
#         } catch (e) {}
#     });
#
#     doAfterLoadEnd(function() {
#         if (!document.querySelector('#gnb') || isMobileDevice() === true) {
#             return;
#         }
#
#         var gnb_src = "https://ssl.pstatic.net/static.gn/templates/gnb_utf8?2023011619";
#
#         // GnbHelper를 이용하여 GNB Layer를 닫을 수 있도록 지원한다.
#         if (window.jindo) {
#             jindo.LazyLoading.load(
#                 gnb_src,
#                 function() {
#                     try {
#                         getGNB();
#                     } catch(e) {}
#                 },
#                 'utf-8'
#             );
#
#             jindo.$Fn(function (oEvent) {
#
#                 GnbHelper.attachClick(oEvent.$value().target);
#             }).attach(document, 'click');
#         } else if (window.jQuery) {
#             new news.JsLoader().
#                 load(
#                     [gnb_src],
#                     function() {
#                         try {
#                             getGNB();
#                         } catch(e) {}
#                     }
#                 );
#
#             $(document).on("click", function(event) {
#                 GnbHelper.attachClick(event.target);
#             });
#         }
#     });
# </script>
#
# <script>
#     doAfterLoadEnd(function() {
#         if (!document.querySelector('.news_header')){
#             return;
#         }
#
#         try {
#             GnbFloatingManager.init();
#         } catch (e) { }
#     });
# </script>
# <script>
# doAfterLoadEnd(function() {
#     try {
#         new SearchAutoComplete({
#             content: document.querySelector("._search_content"),
#             contentToggleBtn: document.querySelector("._search_content_toggle_btn"),
#             isMobile: isMobileDevice(),
#             nClickType: "newsM"
#         });
#     } catch(e) {}
# });
# </script>
# 		<!-- LCS -->
#
#
#
#
# <script type="text/javascript">
#
# function initMa(){
#     var data = {
#         "service": "news",
#         "baseInfo": {
#             "category": (function(){
#
#                 var result = "언론사별(신규)";
#
#                 if(result !== ""){
#                     return result;
#                 }
#                 try{
#
#                     return document.querySelector('meta[property="og:title"]')
#                         .getAttribute('content')
#                         .replace(/[\s]*:+[\s]*네이버[\s]*뉴스/, '');
#                 }catch(e){
#                     return "";
#                 }
#             })()
#         },
#         "extraInfo": {}
#     };
#
#
#
#     try{
#         ma.init({
#             api: "https://ma.news.naver.com/l",
#             data: data
#         });
#     }catch(e){}
# }
# </script>
#
#
# <script type="text/javascript">
#
# if(typeof BMR !== "undefined"){
# 	BMR.run('https://sp.naver.com/sp');
# }
#
#
#
# var eventType = "onpageshow" in window ? "pageshow" : "load";
# jQuery(window).on(eventType, function() {
#
#
#
# lcs_do();
#
#
#     try{
#         initMa();
#     }catch(e){}
# });
# </script>
#
#
# 		<!-- //LCS -->
# 		<div id="videoWrap"></div>
# 	</body>
# </html>

# %%
dom = BeautifulSoup(response.text, "html.parser")
print(dom)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <title id="browserTitleArea">네이버 뉴스</title>
# <script>
# 	function isMobileDevice() {
# 		return /^.*(iPhone|iPod|iPad|Android).*/.test(navigator.userAgent);
# 	}
# </script>
# <script>
# 	(function () {
# 		try {
# 			if (isMobileDevice() && isAbleApplyPrefersColorScheme()) {
#
# 				document.querySelector("html").classList.add("DARK_THEME");
# 			}
# 		} catch(e) {}
#
# 		function isAbleApplyPrefersColorScheme() {
#
# 			if (window.matchMedia("(prefers-color-scheme)").matches === false) {
# 				return false;
# 			}
#
# 			var userAgent = navigator.userAgent;
#
# 			if (userAgent.indexOf("NAVER") > -1) {
#
# 				if (/.*NAVER\([a-zA-Z]*;\s[a-zA-Z]*;\s([0-9]*);/.test(userAgent)) {
# 					return Number(RegExp.$1) >= 1000;
# 				}
# 			} else {
#
# 				return document.cookie.indexOf("NSCS=1") > -1;
# 			}
#
# 			return false;
# 		}
# 	})();
# </script>
# <script>
# 		var g_ssc = 'news.v3_media' || null;
# 		</script>
# <meta charset="utf-8"/>
# <meta content="width=device-width,initial-scale=1.0,maximum-scale=1.0,minimum-scale=1.0,user-scalable=no,target-densitydpi=medium-dpi" name="viewport">
# <link href="https://ssl.pstatic.net/static.news/mnews/resources/20230112_015548/css/generated/newshome.css" rel="stylesheet" type="text/css"/>
# <link href="https://mimgnews.pstatic.net/image/news/m/2014/favicon/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <script>
# 	(function(){
# 		var userAgent = navigator.userAgent;
# 		var result = [];
#
# 		if(userAgent.indexOf('Android') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="72x72" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_hdpi_72X72.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="96x96" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xhdpi_96x96.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="144x144" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxhpdi_144x144.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="192x192" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/android_legacy_xxxhpdi_192x192.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPhone') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="120X120" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_2x_120X120.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="180x180" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPhone_3x_180X180.png" />'
# 			];
# 		}else if(userAgent.indexOf('iPad') > -1){
# 			result = [
# 				'<link rel="apple-touch-icon-precomposed" sizes="167x167" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPadPro_2x_167X167.png" />',
# 				'<link rel="apple-touch-icon-precomposed" sizes="152x152" href="https://ssl.pstatic.net/static.news/image/news/m/2018/favicon/06/iOS_iPad_2x_152X152.png" />'
# 			];
# 		}
# 		document.write(result.join('\n'));
# 	})();
# </script>
# <script src="https://ssl.pstatic.net/static.news/mnews/resources/20230112_015548/js/generated/statistics_jquery.js" type="text/javascript"></script>
# <script>
#     document.documentElement.setAttribute('data-useragent',navigator.userAgent);
# </script>
# <script>
#
# document.documentElement.setAttribute('data-useragent', navigator.userAgent);
#
#
# function showNoImage(elImg, type) {
#     switch (type) {
#
#         case "remove":
#             try {
#                 elImg.parentNode.removeChild(elImg);
#             } catch(e) {}
#             break;
#
#
#         case "removeParent":
#             try {
#                 elImg.parentNode.outerHTML = '';
#             } catch(e) {}
#             break;
#
#
#         case "alt":
#             elImg.outerHTML = ('<span class="noimage_text {imgClassName}">' + (elImg.alt || "") + '</span>')
#
#                 .replace('{imgClassName}', elImg.className);
#             break;
#
#
# 		case "class" :
# 			var outerHTMLSource = Number(elImg.getAttribute("height")) > 0?
#
# 				'<span class="noimage_wrap {imgClassName}" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
# 				'<span class="noimage_wrap {imgClassName}"><span class="noimage"></span></span>';
# 			elImg.outerHTML = outerHTMLSource.replace('{imgClassName}', elImg.className);
# 			break;
#
#
#         default:
#
#             elImg.outerHTML = Number(elImg.getAttribute("height")) > 0?
#
#                 '<span class="noimage_wrap" style="height:' + elImg.getAttribute("height") + 'px;"><span class="noimage"></span></span>':
#                 '<span class="noimage_wrap"><span class="noimage"></span></span>';
#     }
# }
#
#
# function doAfterLoadEnd(callback, callbackOnPersisted) {
#     var eventName = "onpageshow" in window ? "pageshow" : "load";
#
#     callback = callback || function(){};
#     callbackOnPersisted = callbackOnPersisted || function(){};
#
#     window.addEventListener(eventName, function(e) {
#         try{
#             if(Boolean(e.persisted)){
#                 callbackOnPersisted();
#                 return;
#             }
#         }catch(e){}
#
#         callback();
#     });
# }
# </script>
# <meta content="네이버 뉴스" property="og:title"/>
# <meta content="website" property="og:type"/>
# <meta content="https://news.naver.com/main/home.naver" property="og:url"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" property="og:image"/>
# <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" property="og:description"/>
# <meta content="네이버" property="og:article:author"/>
# <meta content="summary" name="twitter:card"/>
# <meta content="네이버 뉴스" name="twitter:title"/>
# <meta content="네이버 뉴스" name="twitter:site"/>
# <meta content="네이버 뉴스" name="twitter:creator"/>
# <meta content="https://ssl.pstatic.net/static.news/image/news/ogtag/navernews_800x420_20221201.png" name="twitter:image"/>
# <meta content="정치, 경제, 사회, 생활/문화, 세계, IT/과학 등 언론사별, 분야별 뉴스 기사 제공" name="twitter:description"/>
# <script>
#
#     (function () {
#         var isUnderIE10 = navigator.appName === "Microsoft Internet Explorer";
#         if (!isUnderIE10) {
#             var script = document.createElement("script");
#             script.async = true;
#             script.src = "https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js";
#             document.head.appendChild(script);
#         }
#     })();
#
#
#     window.gladsdk = window.gladsdk || { cmd: [] };
#     window.gladsdk.cmd.push(function () {
#
#         window.gladsdk.setGlobalConfig({
#             enablePersistAd: true
#         });
#
#
#         var adUnits = [];
#
#         adUnits.push({
#             adUnitId: "p_news_sidebox",
#             adSlotElementId: "glad_ad_sidebox",
#             customParam: {
#                 calp: "home"
#             }
#         });
#
#         for (let i = 0; i < adUnits.length; i++) {
#             window.gladsdk.defineAdSlot(adUnits[i]);
#         }
#
#
#         var htmlClass = document.querySelector("html").getAttribute("class");
#         if (htmlClass && htmlClass.indexOf("DARK_THEME") > -1) {
#             window.gladsdk.setHostMeta("theme", "system");
#         }
#     });
# </script>
# </meta></head>
# <body class="as_mp_layout">
# <div class="u_skip"><a href="#ct">본문 바로가기</a></div>
# <!-- Menu 구분  -->
# <section class="news_header">
# <header class="nh_header" role="banner">
# <div class="Ngnb">
# <div class="Ngnb_inner">
# <div class="Ngnb_both">
# <div class="Ngnb_left">
# <span class="Ngnb_logo"><a class="Nlogo_link" href="https://www.naver.com" onclick="nclk(event,'gnb.naver','','');"><span class="Nicon_logo">NAVER</span></a></span>
# <div class="Ngnb_service">
# <h1 class="Nservice_item"><a href="https://news.naver.com" onclick="nclk(event,'gnb.news','','');"><span class="Nicon_service">뉴스</span></a></h1>
# <span class="Nservice_subitem">
# <a href="https://entertain.naver.com/home" onclick="nclk(event,'gnb.enter','','');">
# <span class="Nicon_family Nicon_entertain">연예</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a href="https://sports.news.naver.com/index" onclick="nclk(event,'gnb.sports','','');">
# <span class="Nicon_family Nicon_sports">스포츠</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a href="https://weather.naver.com/" onclick="nclk(event,'gnb.weather','','');">
# <span class="Nicon_family Nicon_weather">날씨</span>
# </a>
# </span>
# <span class="Nservice_subitem">
# <a href="https://contents.premium.naver.com/" onclick="nclk(event,'gnb.premium','','');">
# <span class="Nicon_family Nicon_premium">프리미엄</span>
# </a>
# </span>
# </div>
# </div>
# <div class="Ngnb_right">
# <div class="Ngnb_group">
# <div class="gnb_dark_type2" id="gnb"></div>
# </div>
# <div class="Ngnb_search is_hidden _search_content"></div>
# <div class="Ngnb_tool">
# <a class="Ntool_button _search_content_toggle_btn" href="javascript:;" onclick="nclk(event,'gnb.sch','','');"><span class="Nicon_search">검색</span></a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="Nlnb _float_lnb">
# <div class="Nlnb_inner">
# <div class="Nlnb_both">
# <div class="Nlnb_left _lnb_scroll">
# <div class="Nlnb_menu Ntype_scroll">
# <div class="Nlnb_menu_inner _scroll">
# <ul class="Nlnb_menu_list" role="menu">
# <li class="Nlist_item is_active"><a aria-selected="true" class="Nitem_link" href="https://news.naver.com/?viewType=pc" onclick="nclk(event,'lnb.pcmedia','','');" role="menuitem"><span class="Nitem_link_menu">언론사별</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=100" onclick="nclk(event,'lnb.pol','','');" role="menuitem"><span class="Nitem_link_menu">정치</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=101" onclick="nclk(event,'lnb.eco','','');" role="menuitem"><span class="Nitem_link_menu">경제</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=102" onclick="nclk(event,'lnb.soc','','');" role="menuitem"><span class="Nitem_link_menu">사회</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=103" onclick="nclk(event,'lnb.lif','','');" role="menuitem"><span class="Nitem_link_menu">생활/문화</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=105" onclick="nclk(event,'lnb.sci','','');" role="menuitem"><span class="Nitem_link_menu">IT/과학</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/main.naver?mode=LSD&amp;mid=shm&amp;sid1=104" onclick="nclk(event,'lnb.wor','','');" role="menuitem"><span class="Nitem_link_menu">세계</span></a></li>
# <li class="Nlist_item _isNew"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/ranking/popularDay.naver" onclick="nclk(event,'lnb.rank','','');" role="menuitem"><span class="Nitem_link_menu">랭킹</span></a></li>
# <li class="Nlist_item _isNew"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/newspaper/home?viewType=pc" onclick="nclk(event,'lnb.paper','','');" role="menuitem"><span class="Nitem_link_menu">신문보기</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/opinion/home" onclick="nclk(event,'lnb.opi','','');" role="menuitem"><span class="Nitem_link_menu">오피니언</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/tv/index.naver?mid=tvh" onclick="nclk(event,'lnb.tv','','');" role="menuitem"><span class="Nitem_link_menu">TV</span></a></li>
# <li class="Nlist_item"><a aria-selected="false" class="Nitem_link" href="https://news.naver.com/main/factcheck/main.naver" onclick="nclk(event,'lnb.fact','','');" role="menuitem"><span class="Nitem_link_menu">팩트체크</span></a></li>
# </ul>
# </div>
# </div>
# </div>
# <div class="Nlnb_right">
# <div class="lnb_extra" id="">
# <div class="lnb_extra_menu">
# <ul class="lnb_extra_menu_list">
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link" href="https://news.naver.com/main/officeList.naver" onclick="nclk(event,'slb.allmedia','','');">전체 언론사</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link" href="https://newsstand.naver.com/" onclick="nclk(event,'slb.newsstand','','');" target="_blank">뉴스스탠드</a></li>
# <li class="lnb_extra_menu_item"><a class="lnb_extra_menu_link" href="https://newslibrary.naver.com/search/searchByDate.naver" onclick="nclk(event,'slb.library','','');" target="_blank">라이브러리</a></li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# </section>
# <hr/>
# <div class="main_wrap" id="ct" role="main">
# <div class="main_container">
# <section class="main_content">
# <h3 class="blind">콘텐츠</h3>
# <div class="main_sublnb">
# <div class="main_sublnb_date">
# <strong>1</strong>.<strong>16</strong><span>(월)</span>
# </div>
# <ul class="main_sublnb_menu">
# <li class="main_sublnb_item"><a class="main_sublnb_link" href="https://news.naver.com/main/officeList.naver " onclick="nclk(event, 'slb.allmedia', '', '')">전체 언론사</a></li>
# <li class="main_sublnb_item"><a class="main_sublnb_link" href="https://newsstand.naver.com/" onclick="nclk(event, 'slb.newsstand', '', '')" target="_blank">뉴스스탠드</a></li>
# <li class="main_sublnb_item"><a class="main_sublnb_link" href="https://newslibrary.naver.com/search/searchByDate.naver" onclick="nclk(event, 'slb.library', '', '')" target="_blank">라이브러리</a></li>
# </ul>
# </div>
# <div class="main_brick">
# <!-- BRICK HOUSE -->
# <div class="grid1_wrap brick-house _brick_gid_wrapper">
# <div class="brick-vowel _brick_column">
# <div class="main_brick_item _press_main_status_wrapper">
# <div class="comp_journal_subscribe">
# <div class="cjs_title_wrap">
# <h3 class="cjs_edit_title">
# <span class="cjs_main">언론사편집</span>
# <a class="cjs_subscribe_a" href="#feedCard" onclick="nclk(event, 'home.editassetting', '', '')">
# <span class="subs_text">기자
#
#                     </span>
# <span class="subs_text">연재
#
#                     </span>
# </a>
# </h3>
# <a class="cjs_more_link" href="https://media.naver.com/channel/settings" onclick="nclk(event, 'home.editsetting', '', '')">
#                 구독설정
#
#                 <span class="ico_more"></span>
# </a>
# </div>
# </div>
# </div>
# <div class="main_brick_item _channel_news_preview_wrapper" data-max-page="16">
# <div class="comp_journal_subscribe _preview_card_page" style="">
# <div class="cjs_channel_card">
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/003" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/003/2022/02/21/logo_003_56_20220221152351.jpg?type=nf76_76_q90" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">뉴시스<span class="datetime">01월 16일 18:29</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="003" data-office_name="뉴시스" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/003/0011645704" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/003/2023/01/16/11645704.jpg?type=nf264_176&amp;ut=20230116165913" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">기체 90도 기울며 추락…네팔 민항기 마지막 순간(영상)</div>
# <p class="cjs_d">네팔의 포카라 신공항 인근에서 추락해 최소 68명이 사망한 민항기의 추락 전후 상황이 담긴 영상이 온라인에서 퍼지고 있다. 15일(현지시간) CNN·데일리메일 등에 따르면 이날 오전 72명이 탄 민항기는 네팔 수도 </p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/087" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/087/2019/08/22/logo_087_56_20190822110222.png?type=nf76_76_q90" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">강원일보<span class="datetime">01월 16일 19:03</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="087" data-office_name="강원일보" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/087/0000947253" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/087/2023/01/16/947253.jpg?type=nf264_176&amp;ut=20230116183403" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">한동훈, '이재명 만난 적 없다' 김성태에 "일종의 말맞추기 신호...그런다고 범죄 수사가 안 되지 않아"</div>
# <p class="cjs_d">한동훈 법무부 장관은 16일 김성태 전 쌍방울그룹 회장이 국내 송환을 앞두고 언론 인터뷰에서 더불어민주당 이재명 대표를 만난 적이 없다고 주장한 것에 대해 "해외 도피한 중범죄자들이 못 견디고 귀국하기 직전에 자기 </p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/094" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/094/2018/09/20/logo_094_56_20180920153620.png?type=nf76_76_q90" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">월간산<span class="datetime">01월 16일 09:17</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="094" data-office_name="월간산" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/094/0000010623" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/094/2023/01/16/10623.jpg?type=nf264_176&amp;ut=20230116070101" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">[거칠부 다이어리] 안나푸르나에서 닭 백숙을 삶다</div>
# <p class="cjs_d">네팔 히말라야에서 안나푸르나만큼 자동차가 깊숙이 들어오는 곳도 없지 싶다. 고소적응에 문제 되지 않는다면, 카트만두에서 마낭Manang(3,540m)까지 이틀이면 갈 수 있다. 사실 처음 안나푸르나에서 걸을 때 가장</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/666" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/666/2023/01/03/logo_666_56_20230103174615.png?type=nf76_76_q90" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">경기일보<span class="datetime">01월 16일 18:17</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="666" data-office_name="경기일보" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/666/0000001656" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/666/2023/01/16/1656.jpg?type=nf264_176&amp;ut=20230116163604" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">'한파도 좋아' 제철 맞은 가평 어비계곡 빙벽 [포토뉴스]</div>
# <p class="cjs_d">경기 동부지역에 한파주의보가 발령된 16일 오후 가평군 어비산 어비계곡 빙벽을 찾은 시민들이 추위에 아랑곳하지 않고 겨울 정취를 만끽하고 있다.</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/277" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img height="28" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/upload/office_logo/277/2018/07/18/logo_277_56_20180718153218.png?type=nf76_76_q90" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">아시아경제<span class="datetime">01월 16일 19:15</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="277" data-office_name="아시아경제" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/277/0005205837" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" loading="lazy" onerror="showNoImage(this)" src="https://mimgnews.pstatic.net/image/origin/277/2023/01/16/5205837.jpg?type=nf264_176&amp;ut=20230116165501" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">또 이 가방 들었네…김건희 여사 '19만원 친환경 백'</div>
# <p class="cjs_d">윤석열 대통령이 김건희 여사와 함께 아랍에미리트(UAE), 스위스 6박 8일 순방길에 오른 가운데 김 여사의 가방에 대한 관심이 높아지고 있다. 김 여사는 아부다비에 도착해 공군 1호기에서 내릴 때 옷은 갈아입었으나</p>
# </div>
# </a>
# </div>
# <div class="cjs_info">
# <button card_type="preview" class="cjs_btn_refresh _refresh_btn" data-max-page="" data-page="0" onclick="nclk(event, 'home.editnfnew', '', '')" size="5" type="button">새로보기</button>
# </div>
# </div>
# </div>
# <div class="comp_journal_subscribe _preview_card_page" style="display:none">
# <div class="cjs_channel_card">
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/665" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/665/2022/12/08/logo_665_56_20221208184224.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">더스쿠프<span class="datetime">01월 16일 14:54</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="665" data-office_name="더스쿠프" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/665/0000000310" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/665/2023/01/16/310.jpg?type=nf264_176&amp;ut=20230116145201" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">"기준 강화해 층간소음 잡겠다?" 탁상공론과 뼈아픈 현실</div>
# <p class="cjs_d">"층간소음 기준을 강화했다. 이로 인해 '층간소음 성가심' 정도는 기존의 절반 수준으로 낮아질 것이다. 층간소음 분쟁에서 피해자가 피해를 인정받을 가능성도 높아졌다." 지난해 12월 30일 환경부와 국토교통부가 '공</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/127" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/127/2020/04/02/logo_127_56_20200402162102.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">기자협회보<span class="datetime">01월 14일 22:28</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="127" data-office_name="기자협회보" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/127/0000033569" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/127/2023/01/13/33569.jpg?type=nf264_176&amp;ut=20230113101201" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">한국일보 '김만배 돈거래' 간부 해고</div>
# <p class="cjs_d">한국일보가 대장동 개발사업 비리 의혹 사건의 핵심 인물인 김만배씨와 돈거래한 뉴스룸국 간부를 해고했다. 한국일보는 13일 신문 1면에 '독자와 국민께 깊이 사과드립니다'라는 글을 실어 "본사 뉴스룸국 간부가 대장동 </p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/016" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/016/2020/11/03/logo_016_56_20201103113832.jpg?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">헤럴드경제<span class="datetime">01월 16일 19:15</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="016" data-office_name="헤럴드경제" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/016/0002091563" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/016/2023/01/16/2091563.jpg?type=nf264_176&amp;ut=20230116185501" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">“월 60만원에 주말·야근 풀근무?” 얘 때문에 알바 자리 뺏겼다</div>
# <p class="cjs_d">“월급 60만원에 주말·야근도 할 수 있느냐며, 더는 사람 안 뽑는다 하더라고요.” 서울 마포구에 거주하는 A(35)씨. 회사 그만두고 식당 아르바이트 자리를 알아봤다. 단골식당에 평소 손이 부족하단 걸 알고 있던 </p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/028" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/028/2018/08/01/logo_028_56_20180801163801.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">한겨레<span class="datetime">01월 16일 19:02</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="028" data-office_name="한겨레" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/028/0002623588" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/028/2023/01/16/2623588.jpg?type=nf264_176&amp;ut=20230116175504" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">검찰, 이재명에 또 소환 통보…이번엔 ‘대장동 개발 특혜’ 의혹</div>
# <p class="cjs_d">검찰이 ‘대장동 개발 특혜 의혹’ 등에 연루된 이재명 더불어민주당 대표에게 출석을 통보했다. 서울중앙지검 반부패수사1부(부장 엄희준)·3부(부장 강백신)는 배임 및 부패방지법 위반 등 혐의를 받는 이재명 대표 쪽에 </p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/437" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/437/2020/08/25/logo_437_56_20200825135552.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">JTBC<span class="datetime">01월 16일 18:45</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="437" data-office_name="JTBC" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/437/0000328952" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/437/2023/01/16/328952.jpg?type=nf264_176&amp;ut=20230116184501" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">[단독] '또 다른 징용 현장' 사도광산 명부 입수…"조선인 사망자 9명"</div>
# <p class="cjs_d">일본 정부가 지난 1992년 우리 정부에 직접 건넨 조선인 강제노역 명부 중 일부를 JTBC가 입수했습니다. 노태우 전 대통령은 1990년 국빈 자격으로 일본에 갔을 때 일본 정부에 '강제연행자' 명부를 요청했고, </p>
# </div>
# </a>
# </div>
# <div class="cjs_info">
# <button card_type="preview" class="cjs_btn_refresh _refresh_btn" data-max-page="" data-page="0" onclick="nclk(event, 'home.editnfnew', '', '')" size="5" type="button">새로보기</button>
# </div>
# </div>
# </div>
# <div class="comp_journal_subscribe _preview_card_page" style="display:none">
# <div class="cjs_channel_card">
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/015" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/015/2020/08/11/logo_015_56_20200811194037.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">한국경제<span class="datetime">01월 16일 19:08</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="015" data-office_name="한국경제" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/015/0004800109" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/015/2023/01/16/4800109.jpg?type=nf264_176&amp;ut=20230116185601" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">"지금 주문하면 3월에나"…김건희 여사 또 들자 '품절 대란'</div>
# <p class="cjs_d">윤석열 대통령의 아랍에미리트(UAE)·스위스 순방길에서 배우자 김건희 여사의 단골 패션 아이템인 가방이 다시 한번 노출돼 품절 사태를 빚었다. 김 여사가 외교무대에 등장할 때 자주 든 국내 새활용(업사이클) 패션 브</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/033" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/033/2018/09/20/logo_033_56_20180920152820.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">주간경향<span class="datetime">01월 16일 14:54</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="033" data-office_name="주간경향" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/033/0000045147" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/033/2023/01/16/45147.jpg?type=nf264_176&amp;ut=20230116091401" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">9·19 합의 정지하면 대북확성기 켜도 돼?</div>
# <p class="cjs_d">설 대화 7첩반상 다시 설입니다. 코로나19가 여전하고 실내 마스크 착용 의무도 해제되지 않았지만, 얼굴을 맞대기조차 어려웠던 지난 3년과 비교하면 이번 설은 그래도 오랜만에 가족, 친지들이 한자리에 모일 소중한 기</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/660" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/660/2022/01/19/logo_660_56_20220119141745.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">kbc광주방송<span class="datetime">01월 16일 19:14</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="660" data-office_name="kbc광주방송" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/660/0000026279" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/660/2023/01/16/26279.jpg?type=nf264_176&amp;ut=20230116184401" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# <span class="comp_ico_movie">동영상</span>
# <span class="comp_playtime"><span class="time"><span class="blind">재생시간</span>15:29</span></span>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">박지원 “尹, 모두가 차렷 할 때 나홀로 UAE 국기에 경례..왜 그런지 몰라”[여의도초대석]</div>
# <p class="cjs_d">△ 유재광 앵커: 서울 여의도 광역방송센터입니다. ‘여의도초대석’ 박지원 전 국가정보원장과 함께 정치권 현안 이슈 짚어보겠습니다. 원장님 어서 오십시오. ▲ 박지원 전 국가정보원장: 네. 안녕하세요. 연속 2주 지난</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/006" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/006/2018/07/18/logo_006_56_20180718152218.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">미디어오늘<span class="datetime">01월 16일 17:19</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="006" data-office_name="미디어오늘" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/006/0000116418" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/006/2023/01/16/116418.jpg?type=nf264_176&amp;ut=20230116134201" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">점수도 명단도 비공개… TBS 차기대표 후보 추천도 '암흑심사'</div>
# <p class="cjs_d">TBS 임원추천위원회가 진행하는 차기대표 추천 절차가 16일 마무리된다. 임추위 2차 면접과 서울시 최종후보 추천명단 제출이 모두 16일 하루에 이뤄지는 것으로 확인됐다. 차기대표 최종임명권이 서울시장에 있고 후보 </p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/011" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/011/2022/07/29/logo_011_56_20220729150242.jpg?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">서울경제<span class="datetime">01월 16일 18:29</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="011" data-office_name="서울경제" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/011/0004145543" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/011/2023/01/16/4145543.jpg?type=nf264_176&amp;ut=20230116162101" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">강남 음식점 여사장 ‘알몸시위’ 왜…"건물주 고발합니다"</div>
# <p class="cjs_d">강남에서 육회집을 운영하는 여사장이 보증금 150%, 월세 40% 인상을 요구하는 건물주에 분노해 나체 흉기 시위를 벌였다. 지난 14일 유튜브 채널 ‘명탐정 카라큘라’에는 ‘강남역 육회집 여사장 나체 할복 사건’이</p>
# </div>
# </a>
# </div>
# <div class="cjs_info">
# <button card_type="preview" class="cjs_btn_refresh _refresh_btn" data-max-page="" data-page="0" onclick="nclk(event, 'home.editnfnew', '', '')" size="5" type="button">새로보기</button>
# </div>
# </div>
# </div>
# <div class="comp_journal_subscribe _preview_card_page" style="display:none">
# <div class="cjs_channel_card">
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/020" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/020/2020/09/17/logo_020_56_20200917112548.jpg?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">동아일보<span class="datetime">01월 16일 18:58</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="020" data-office_name="동아일보" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/020/0003474259" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/020/2023/01/16/3474259.jpg?type=nf264_176&amp;ut=20230116164602" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">中 ‘일대일로’로 지은 네팔 공항서 추락 사고…부실 공사 의혹도</div>
# <p class="cjs_d">문을 연 지 보름만인 15일 최소 68명이 숨진 여객기 추락사고가 발생한 네팔 포카라 국제공항이 중국 경제영토 확장 사업 일대일로(一帶一路) 프로젝트를 통해 건설됐다는 사실이 다시 부각되고 있다. 일부 외신은 부실 </p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/656" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/656/2022/01/19/logo_656_56_20220119134936.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">대전일보<span class="datetime">01월 16일 17:37</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="656" data-office_name="대전일보" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/656/0000040357" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/656/2023/01/16/40357.jpg?type=nf264_176&amp;ut=20230116162001" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">[영상] 기내 흔들리더니 순식간에 '쾅'…네팔 항공기 추락 순간</div>
# <p class="cjs_d">네팔 여객기 추락 사고 당시 탑승객이던 한 남성이 촬영한 사고 당시 상황이 고스란히 담긴 페이스북 라이브 영상이 공개되며 안타까움을 사고 있다. 16일 영국 데일리메일, 인도 매체 타임스오브인디아 등 다수의 외신에 </p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/001" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/001/2020/08/11/logo_001_56_20200811154916.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">연합뉴스<span class="datetime">01월 16일 19:14</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="001" data-office_name="연합뉴스" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/001/0013703687" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/001/2023/01/16/13703687.jpg?type=nf264_176&amp;ut=20230116163318" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">"네팔 경찰, 추락 여객기 사망자 중 한국인 1명 신원 확인"</div>
# <p class="cjs_d">신원 파악 26명 가운데 40대 유모씨 포함…10대 아들 생사는 불명 김영현 특파원 = 네팔 경찰이 지난 15일(현지시간) 중부 포카라에 추락한 '한국인 2명 탑승' 여객기 사고와 관련해 신원이 확인된 사망자 명단에</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/262" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/262/2018/09/20/logo_262_56_20180920153820.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">신동아<span class="datetime">01월 16일 10:18</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="262" data-office_name="신동아" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/262/0000016197" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/262/2023/01/16/16197.jpg?type=nf264_176&amp;ut=20230116100205" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">은행 희망퇴직은 ‘돈 잔치’… 노조도 대상 확대 요구</div>
# <p class="cjs_d">“특별퇴직금 5억 원 받고 인생2막 열겠다” ● 5大 은행 올해 3000명가량 희망퇴직 전망 ● 역대급 실적에 희망퇴직 희망하는 행원들 ● 대상 연령 40대까지… ‘칼바람’ 아닌 ‘잔치’ ● 고금리 속 ‘퇴직금 잔치</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/050" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/050/2021/07/15/logo_050_56_20210715110055.jpg?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">한경비즈니스<span class="datetime">01월 16일 08:53</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="050" data-office_name="한경비즈니스" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/050/0000063710" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/050/2023/01/16/63710.jpg?type=nf264_176&amp;ut=20230116060217" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">캠핑 인구 700만 시대, 커져 가는 RV 시장</div>
# <p class="cjs_d">‘700만 명.’ 2022년 한국의 캠핑 인구수다. 코로나19 사태 이후 200만 명 정도 늘었다. 캠핑 문화가 확산되면서 낚시인과 등산객 등이 쪽잠을 자던 차박(차 안에서 잠을 자는 캠핑)은 옛말이 됐다. 오히려 </p>
# </div>
# </a>
# </div>
# <div class="cjs_info">
# <button card_type="preview" class="cjs_btn_refresh _refresh_btn" data-max-page="" data-page="0" onclick="nclk(event, 'home.editnfnew', '', '')" size="5" type="button">새로보기</button>
# </div>
# </div>
# </div>
# <div class="comp_journal_subscribe _preview_card_page" style="display:none">
# <div class="cjs_channel_card">
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/640" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/640/2020/05/06/logo_640_56_20200506111106.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">코리아중앙데일리<span class="datetime">01월 16일 19:13</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="640" data-office_name="코리아중앙데일리" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/640/0000033920" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/640/2023/01/16/33920.jpg?type=nf264_176&amp;ut=20230116182201" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">Korean victims in Nepal crash were father and son</div>
# <p class="cjs_d">The two Koreans on board a plane that crashed in Nepal on Sunday were a father and a son surnamed Yu, according to fligh</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/079" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/079/2018/07/18/logo_079_56_20180718152918.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">노컷뉴스<span class="datetime">01월 16일 19:05</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="079" data-office_name="노컷뉴스" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/079/0003728123" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/079/2023/01/16/3728123.jpg?type=nf264_176&amp;ut=20230116184701" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">윤 대통령, 또 타국 국가 연주때 홀로 가슴 손[어텐션 뉴스]</div>
# <p class="cjs_d">온라인 핫 뉴스만 콕콕…[어텐션 뉴스] CBS 정다운의 뉴스톡 530 ■ 방송 : CBS 라디오 '정다운의 뉴스톡 530' ■ 채널 : 표준FM 98.1 (17:30~18:00) ■ 진행 : 정다운 앵커 [앵커] 오</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/659" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# <img data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/659/2022/01/19/logo_659_56_20220119141438.png?type=nf76_76_q90" height="28" loading="lazy" onerror="showNoImage(this)" width="28"/>
# </div>
# <div class="cjs_ctw">
# <h4 class="channel">전주MBC<span class="datetime">01월 16일 18:22</span></h4>
# </div>
# </a>
# <div class="cjs_ctitle_right">
# <button class="cjs_btn_subscribe _subscribe_btn" data-office_id="659" data-office_name="전주MBC" onclick="nclk(event, 'home.editnfset', '', '')" type="button">구독</button>
# </div>
# </div>
# <div class="cjs_journal_wrap _item_contents">
# <a class="cjs_news_a _cds_link _editn_link" href="https://n.news.naver.com/article/659/0000008492" onclick="nclk(event, 'home.editnfimg', '', '')">
# <div class="cjs_news_mw">
# <img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/659/2023/01/16/8492.jpg?type=nf264_176&amp;ut=20230116175001" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="cjs_news_tw">
# <div class="cjs_t">"외유성 연수에 배우자 참여".. 지역 농협 조합장 고발</div>
# <p class="cjs_d">◀앵커▶ 오는 3월 조합장 선거를 앞두고 선관위가 완주의 한 지역 농협 조합장을 경찰에 고발했습니다. 농협 임직원들의 연수에 배우자들을 포함시켜 식사와 이동 편의 등을 제공했는데, 선관위는 이를 불법 기부행위라고 보</p>
# </div>
# </a>
# </div>
# <div class="cjs_ctitle _item_title">
# <a class="cjs_ctitle_a" href="https://media.naver.com/press/607" onclick="nclk(event, 'home.editnfmedia', '', '')">
# <div class="cjs_cmw small">
# ...
# <span class="css_state _is_subscribe" style="display: none">구독중</span>
# <button class="css_btn_subscribe _subscribe_btn" data-channel_group="HOT_SERIES" data-channel_key="HS_1087793" data-channel_name="글로벌 리포트" onclick="nclk(event, 'home.editstake', '', '')" type="button">구독</button>
# </div>
# </div>
# <a class="css_series_a _cds_link" href="https://n.news.naver.com/mnews/hotissue/article/014/0004955779?cid=1087793" onclick="nclk(event, 'home.editseriescont', '', '')">
# <span class="blind">글로벌 리포트</span>
# </a>
# </div>
# </li>
# <li class="css_reporter_item _item" style="display:none">
# <div class="css_series_card">
# <div class="css_smw">
# <img alt="" class="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/015/2023/01/15/4799579.jpg?type=nf324_192" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="css_stw">
# <h4 class="css_series_title">
# <span class="css_stitle">
#                                         2023년 증시, 재붕괴설 vs 골디락스론 대논쟁 [한상춘의 국제경제 읽기]
#                                     </span>
# </h4>
# <a class="css_series _cds_link" href="https://news.naver.com/main/hotissue/sectionList.naver?mid=hot&amp;sid1=110&amp;cid=1064780" onclick="nclk(event, 'home.editseries', '', '')">
# <div class="css_sthumb"><img alt="" data-onshow-src="https://imgnews.pstatic.net/image/upload/component/2017/08/30/161448229_0002849325_001_20170830033755512.jpg?type=nf40_40" height="20" loading="lazy" onerror="showNoImage(this)" width="20"/></div>
# <div class="css_sname">한상춘의 국제경제 읽기</div>
# </a>
# <div class="css_state_wrap _subscribe_wrapper">
# <span class="css_state _is_subscribe" style="display: none">구독중</span>
# <button class="css_btn_subscribe _subscribe_btn" data-channel_group="HOT_SERIES" data-channel_key="HS_1064780" data-channel_name="한상춘의 국제경제 읽기" onclick="nclk(event, 'home.editstake', '', '')" type="button">구독</button>
# </div>
# </div>
# <a class="css_series_a _cds_link" href="https://n.news.naver.com/mnews/hotissue/article/015/0004799579?cid=1064780" onclick="nclk(event, 'home.editseriescont', '', '')">
# <span class="blind">한상춘의 국제경제 읽기</span>
# </a>
# </div>
# </li>
# <li class="css_reporter_item _item" style="display:none">
# <div class="css_series_card">
# <div class="css_smw">
# <img alt="" class="" data-onshow-src="https://mimgnews.pstatic.net/image/origin/469/2023/01/15/718406.jpg?type=nf324_192" loading="lazy" onerror="showNoImage(this)" width="100%"/>
# </div>
# <div class="css_stw">
# <h4 class="css_series_title">
# <span class="css_stitle">
#                                         6세 초등생이 교실에서 총격을...미국선 처음 아니었다[특파원 24시]
#                                     </span>
# </h4>
# <a class="css_series _cds_link" href="https://news.naver.com/main/hotissue/sectionList.naver?mid=hot&amp;sid1=110&amp;cid=1085867" onclick="nclk(event, 'home.editseries', '', '')">
# <div class="css_sthumb"><img alt="" data-onshow-src="https://mimgnews.pstatic.net/image/upload/office_logo/469/2017/01/05/logo_469_18_20170105111205.png?type=nf40_40" height="20" loading="lazy" onerror="showNoImage(this)" width="20"/></div>
# <div class="css_sname">특파원 24시</div>
# </a>
# <div class="css_state_wrap _subscribe_wrapper">
# <span class="css_state _is_subscribe" style="display: none">구독중</span>
# <button class="css_btn_subscribe _subscribe_btn" data-channel_group="HOT_SERIES" data-channel_key="HS_1085867" data-channel_name="특파원 24시" onclick="nclk(event, 'home.editstake', '', '')" type="button">구독</button>
# </div>
# </div>
# <a class="css_series_a _cds_link" href="https://n.news.naver.com/mnews/hotissue/article/469/0000718406?cid=1085867" onclick="nclk(event, 'home.editseriescont', '', '')">
# <span class="blind">특파원 24시</span>
# </a>
# </div>
# </li>
# </ul>
# <div class="css_info">
# <button class="css_btn_refresh _refresh_btn" onclick="nclk(event, 'home.editsnmore', '', '')" type="button"></button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="brick-vowel _brick_column">
# </div>
# <div class="brick-vowel _brick_column">
# </div>
# </div>
# </div>
# </section>
# <section class="main_aside _aside_wrapper">
# <div class="main_aside_inner _aside_content">
# <h3 class="blind">구독</h3>
# <div class="_aside"></div>
# <script>
# doAfterLoadEnd(loadAside);
#
#
# function loadAside() {
#     var forcePcVersion = "";
#
#     if (isMobileDevice() && !forcePcVersion) {
#         return;
#     }
#     var iframe = append();
#     var asideFixed;
#
#     window.addEventListener('message', function(event) {
#         var data = event.data;
#
#         if (event.origin !== "https://news.naver.com") {
#             return;
#         }
#
#         if (data.type === "setIframeSize" && data.height) {
#             iframe.style.height = data.height + 'px';
#             iframe.style.visibility = "";
#
#             try {
#                 asideFixed.deactivate(); // event 중복 적용되지 않게
#             } catch(e) {}
#
#             asideFixed = AsideFixed({
#                 "wrapper" : document.querySelector("._aside_wrapper")
#
#             });
#         }
#     });
#
#
#     function append() {
#         var iframe = document.createElement('iframe');
#
#         iframe.width = "100%";
#         iframe.height = "0";
#         iframe.style.visibility = "hidden";
#         iframe.setAttribute("frameborder", "no");
#         iframe.setAttribute("scrolling", "no");
#         iframe.src = "https://news.naver.com/aside?oid=";
#
#         document.querySelector("._aside").appendChild(iframe);
#
#         return iframe;
#     }
# }
# </script>
# </div>
# </section>
# <div class="layer_toast" style="display: none"></div>
# <div class="layer_toast_journal_subscribe _subscribe_toast_layer" style="display: none">
# <button class="lt_btn_set _subscribe_toast_btn" onclick="nclk(event, 'home.edittallchk', '', '')" type="button"></button>
# </div>
# </div>
# </div>
#
# <!-- //ct -->
# <hr/>
# <div class="mp_footer">
# <div class="f_subinfo">
# <div class="f_subinfoinner">
# <div class="f_notice">
# <h5 class="f_notice_badge">공지</h5>
# <a class="f_notice_link" data-mpurl='{"m":"https://m.news.naver.com/ombudsman/noticeread?notiId=707","p":"https://news.naver.com/main/ombudsman/readView.naver?notiId=707"}' href="https://m.news.naver.com/ombudsman/noticeread?notiId=707" onclick="nclk(event, 'fot.noticetext', '', '');">
# <p class="f_notice_text">위클리 심층 키워드 출시 안내</p>
# </a>
# </div>
# </div>
# </div>
# <div class="f_maininfo">
# <div class="f_maininfoinner">
# <a class="r_pg_top _go_top" href="javascript:;" id="goTop" onclick="nclk(event, 'fot.pctop', '', '');">맨위로</a>
# <footer role="contentinfo">
# <p class="u_ftlkw _footer_login" id="u_ftlkw">
# <a class="u_ftlk" data-mpurl='{"m":"https://m.naver.com/services.html","p":"https://www.naver.com/more.html"}' href="https://m.naver.com/services.html" onclick="nclk(event,'fot.serviceall','','');">전체서비스</a>
# </p>
# <p class="u_cr">
# <span class="u_ftm">
# <span class="u_cri u_cri_v1"><a class="u_cra" data-mpurl='{"m":"https://policy.naver.com/policy-mobile/term.html?type=1?type=1","p":"https://policy.naver.com/rules/service.html"}' href="https://policy.naver.com/policy-mobile/term.html?type=1?type=1" onclick="nclk(event,'fot.agreement','','');">이용약관</a></span>
# <span class="u_cri u_cri_v1"><a class="u_cra" data-mpurl='{"m":"https://policy.naver.com/policy-mobile/privacy.html","p":"https://policy.naver.com/rules/privacy.html"}' href="https://policy.naver.com/policy-mobile/privacy.html" onclick="nclk(event,'fot.privacy','','');"><strong>개인정보처리방침</strong></a></span>
# <span class="u_cri u_cri_v1">청소년 보호 책임자 : 이희만</span>
# <span class="u_cri u_cri_v1"><a class="u_cra" data-mpurl='{"m":"https://m.news.naver.com/ombudsman/index","p":"https://news.naver.com/main/ombudsman/index.naver"}' href="https://m.news.naver.com/ombudsman/index" onclick="nclk(event,'fot.guide','','');">서비스안내</a></span>
# </span>
# <span class="u_cri">각 언론사가 직접 콘텐츠를 편집합니다.</span>
# </p>
# </footer>
# </div>
# </div>
# </div>
# <script src="https://ssl.pstatic.net/static.news/mnews/resources/20230112_015548/js/generated/news.mobile.js" type="text/javascript"></script>
# <script src="https://ssl.pstatic.net/static.news/mnews/resources/20230112_015548/js/generated/pressmain.dependency.js" type="text/javascript"></script>
# <script type="text/javascript">
# /**
#  * 이 파일은 모바일 뉴스 서비스 전체 페이지에 적용되는 스크립트로써,
#  * 코드 추가 시 Front-End 성능 관점에서 주의를 요합니다.
#  */
# jQuery(window).on('load', function(){
#     setTimeout(onload, 10);
#
#     function onload(){
#         var oLnb = new news.Lnb('._lnb_scroll');
#         new news.ImageLazyLoader().load("img[data-src]");
#         new news.MoveTopButton("._go_top");
#
#
#         new news.HistoryManager().init("naver_mobile_news_history", "");
#
#         // iframe lazy-loading
#         (function(){
#             try {
#                 Array.prototype.slice.apply(document.querySelectorAll('iframe[data-src]'))
#                     .forEach(function(iframeEl) {
#                         var originSrc = iframeEl.getAttribute('data-src');
#                         if(originSrc) {
#                             iframeEl.setAttribute('src', originSrc);
#                         }
#                     });
#             }catch(e) {}
#         })();
#
#         if(typeof init === "function"){
#             init();
#         }
#
#         var cookie = news.Cookie.getInstance();
#         var isShownNewLnb = cookie.getItem("isShownNewLnb");
#         if(isShownNewLnb == null) {
#             isShownNewLnb = "Y";
#             cookie.setItem("isShownNewLnb", isShownNewLnb, 3650, "", "/");
#             $("._isNew").addClass("is_new");
#         }
#
#         {
#             var footerLogin = jQuery(document).find('._footer_login');
#             if(footerLogin <= 0) {
#                 return;
#             }
#
#             // 디바이스에 따라 로그인, 로그아웃 URL 분기
#             var loginUrl = "https://nid.naver.com/nidlogin.login";
#             var logoutUrl = "https://nid.naver.com/nidlogin.logout?";
#             if (news.Util.getAgentInfo().bMobileOrTablet) {
#                 loginUrl = "https://nid.naver.com/nidlogin.login?svctype=262144";
#                 logoutUrl = "https://nid.naver.com/nidlogin.logout?svctype=262144&";
#             }
#
#             if(news.LoginAssistor.isLoginUser()) {
#                 footerLogin.prepend('<a href="javascript:news.Util.logout(\''+logoutUrl+'url=\'+encodeURIComponent(location.href));" class="u_ftlk" id="news_logout" onclick="nclk(event,\'fot.logout\',\'\',\'\');" >로그아웃</a>')
#             }else {
#                 footerLogin.prepend('<a href="'+loginUrl+'" class="u_ftlk" id="news_login" onclick="nclk(event,\'fot.login\',\'\',\'\');" >로그인</a>')
#             }
#         }
#     }
# });
# </script>
# <script id="feedRefreshButtonTemplate" type="text/x-handlebars-template">
#     새로보기
#     <span class="paging">
#         <span class="blind">현재</span>{{currentPage}}
#         <em class="total"> / <span class="blind">전체</span>{{totalPage}}</em>
#     </span>
# </script>
# <script type="text/javascript">
#     BrickGridForEditByPress($("._brick_gid_wrapper"));
#     PressMainStatusCard($('._press_main_status_wrapper'));
#     NewsFlashCard($('._newsflash_wrapper'));
#     FeedCard($('._journalist_feed_card_wrapper'), 'journalist', 'https://m.news.naver.com');
#     FeedCard($('._series_feed_card_wrapper'), 'series', 'https://m.news.naver.com');
#
#
#
#     window.gladsdk.cmd.push(function () {
#         var adSlot = window.gladsdk.findAdSlot("glad_ad_sidebox");
#         adSlot.setCustomParam("calp", 'home');
#         window.gladsdk.displayAd(adSlot);
#
#
#         window.gladsdk.addEventListener(window.gladsdk.event.ERROR, function (ad, error) {
#             $("._card_ad").hide();
#         });
#     });
#
#     $('._channel_news_card_wrapper').each(function () {
#         var wrapper = $(this);
#         ChannelNewsCard(wrapper, 'https://m.news.naver.com');
#     })
#
#     ChannelNewsPreviewCard($('._channel_news_preview_wrapper'), 'https://m.news.naver.com');
#     SubscribeBannerShortCard($('._short_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#     SubscribeBannerLongCard($('._long_subscribe_banner_card_wrapper'), 'https://m.news.naver.com');
#
#     WeeklySpecialReportCard($('._weekly_special_report_card_wrapper'));
#
#     $('._horizontal_card_wrapper').each(function () {
#         var wrapper = $(this);
#         HorizontalTypeCard(wrapper, 'https://m.news.naver.com');
#     });
#
#     SpecialReportCard($('._special_report_card_wrapper'), 'https://m.news.naver.com');
#
#     ArticleLinkParamsAppender('news_media_pc');
#
#
#     (function () {
#       var seriesFeedCard = $('._series_feed_card_wrapper');
#       var seriesOffset = getOffset(seriesFeedCard);
#       var journalistFeedCard = $('._journalist_feed_card_wrapper');
#       var journalistOffset = getOffset(journalistFeedCard);
#       var targetCard = seriesOffset > journalistOffset ? journalistFeedCard : seriesFeedCard;
#       targetCard.find('._feed_card_anchor').attr('id', 'feedCard');
#
#       function getOffset (target) {
#         if (target[0]) {
#           return  target.offset().top;
#         }
#         return Number.MAX_VALUE;
#       }
#     })();
# </script>
# <script>
#     var gnb_service = 'news';
#     var gnb_logout = encodeURIComponent(location.href);
#     var gnb_template = 'gnb_utf8';
#     var gnb_brightness = 3;
#
#     doAfterLoadEnd(function () {
#         try {
#             GlobalMPUrlManager.init();
#         } catch (e) {}
#     });
#
#     doAfterLoadEnd(function() {
#         if (!document.querySelector('#gnb') || isMobileDevice() === true) {
#             return;
#         }
#
#         var gnb_src = "https://ssl.pstatic.net/static.gn/templates/gnb_utf8?2023011619";
#
#         // GnbHelper를 이용하여 GNB Layer를 닫을 수 있도록 지원한다.
#         if (window.jindo) {
#             jindo.LazyLoading.load(
#                 gnb_src,
#                 function() {
#                     try {
#                         getGNB();
#                     } catch(e) {}
#                 },
#                 'utf-8'
#             );
#
#             jindo.$Fn(function (oEvent) {
#
#                 GnbHelper.attachClick(oEvent.$value().target);
#             }).attach(document, 'click');
#         } else if (window.jQuery) {
#             new news.JsLoader().
#                 load(
#                     [gnb_src],
#                     function() {
#                         try {
#                             getGNB();
#                         } catch(e) {}
#                     }
#                 );
#
#             $(document).on("click", function(event) {
#                 GnbHelper.attachClick(event.target);
#             });
#         }
#     });
# </script>
# <script>
#     doAfterLoadEnd(function() {
#         if (!document.querySelector('.news_header')){
#             return;
#         }
#
#         try {
#             GnbFloatingManager.init();
#         } catch (e) { }
#     });
# </script>
# <script>
# doAfterLoadEnd(function() {
#     try {
#         new SearchAutoComplete({
#             content: document.querySelector("._search_content"),
#             contentToggleBtn: document.querySelector("._search_content_toggle_btn"),
#             isMobile: isMobileDevice(),
#             nClickType: "newsM"
#         });
#     } catch(e) {}
# });
# </script>
# <!-- LCS -->
# <script type="text/javascript">
#
# function initMa(){
#     var data = {
#         "service": "news",
#         "baseInfo": {
#             "category": (function(){
#
#                 var result = "언론사별(신규)";
#
#                 if(result !== ""){
#                     return result;
#                 }
#                 try{
#
#                     return document.querySelector('meta[property="og:title"]')
#                         .getAttribute('content')
#                         .replace(/[\s]*:+[\s]*네이버[\s]*뉴스/, '');
#                 }catch(e){
#                     return "";
#                 }
#             })()
#         },
#         "extraInfo": {}
#     };
#
#
#
#     try{
#         ma.init({
#             api: "https://ma.news.naver.com/l",
#             data: data
#         });
#     }catch(e){}
# }
# </script>
# <script type="text/javascript">
#
# if(typeof BMR !== "undefined"){
# 	BMR.run('https://sp.naver.com/sp');
# }
#
#
#
# var eventType = "onpageshow" in window ? "pageshow" : "load";
# jQuery(window).on(eventType, function() {
#
#
#
# lcs_do();
#
#
#     try{
#         initMa();
#     }catch(e){}
# });
# </script>
# <!-- //LCS -->
# <div id="videoWrap"></div>
# </body>
# </html>

# %%
print(dom.select(".cjs_news_tw .cjs_t"))
# Out:
# [<div class="cjs_t">기체 90도 기울며 추락…네팔 민항기 마지막 순간(영상)</div>, <div class="cjs_t">한동훈, '이재명 만난 적 없다' 김성태에 "일종의 말맞추기 신호...그런다고 범죄 수사가 안 되지 않아"</div>, <div class="cjs_t">[거칠부 다이어리] 안나푸르나에서 닭 백숙을 삶다</div>, <div class="cjs_t">'한파도 좋아' 제철 맞은 가평 어비계곡 빙벽 [포토뉴스]</div>, <div class="cjs_t">또 이 가방 들었네…김건희 여사 '19만원 친환경 백'</div>, <div class="cjs_t">"기준 강화해 층간소음 잡겠다?" 탁상공론과 뼈아픈 현실</div>, <div class="cjs_t">한국일보 '김만배 돈거래' 간부 해고</div>, <div class="cjs_t">“월 60만원에 주말·야근 풀근무?” 얘 때문에 알바 자리 뺏겼다</div>, <div class="cjs_t">검찰, 이재명에 또 소환 통보…이번엔 ‘대장동 개발 특혜’ 의혹</div>, <div class="cjs_t">[단독] '또 다른 징용 현장' 사도광산 명부 입수…"조선인 사망자 9명"</div>, <div class="cjs_t">"지금 주문하면 3월에나"…김건희 여사 또 들자 '품절 대란'</div>, <div class="cjs_t">9·19 합의 정지하면 대북확성기 켜도 돼?</div>, <div class="cjs_t">박지원 “尹, 모두가 차렷 할 때 나홀로 UAE 국기에 경례..왜 그런지 몰라”[여의도초대석]</div>, <div class="cjs_t">점수도 명단도 비공개… TBS 차기대표 후보 추천도 '암흑심사'</div>, <div class="cjs_t">강남 음식점 여사장 ‘알몸시위’ 왜…"건물주 고발합니다"</div>, <div class="cjs_t">中 ‘일대일로’로 지은 네팔 공항서 추락 사고…부실 공사 의혹도</div>, <div class="cjs_t">[영상] 기내 흔들리더니 순식간에 '쾅'…네팔 항공기 추락 순간</div>, <div class="cjs_t">"네팔 경찰, 추락 여객기 사망자 중 한국인 1명 신원 확인"</div>, <div class="cjs_t">은행 희망퇴직은 ‘돈 잔치’… 노조도 대상 확대 요구</div>, <div class="cjs_t">캠핑 인구 700만 시대, 커져 가는 RV 시장</div>, <div class="cjs_t">Korean victims in Nepal crash were father and son</div>, <div class="cjs_t">윤 대통령, 또 타국 국가 연주때 홀로 가슴 손[어텐션 뉴스]</div>, <div class="cjs_t">"외유성 연수에 배우자 참여".. 지역 농협 조합장 고발</div>, <div class="cjs_t">이상민에게 '이태원 참사'와  '2차 가해'의 책임을 물었다</div>, <div class="cjs_t">"한국 청소년들 소름 돋는다"…K드라마 학폭에 세계가 놀랐다</div>, <div class="cjs_t">‘비밀번호 변경’ 긴급 메일⋯알고 보니 북한발 해킹시도</div>, <div class="cjs_t">5대 은행 평균연봉 1억?…"예대마진 폭리, 횡재세 부과해라" 네티즌 냉소 [e라이프]</div>, <div class="cjs_t">[심층] 학원가 재수행렬 이어져</div>, <div class="cjs_t">동탄 집값 5억~6억씩 ‘뚝뚝’…신규 분양에 선착순 계약 등장</div>, <div class="cjs_t">국내 최초 美 FDA 승인 획득, 한국 제약산업 선도한 종근당</div>, <div class="cjs_t">'개코'가 건강? ... 후각은 '노화'의 지표</div>, <div class="cjs_t">"애플워치 기능 확대" 규제샌드박스'노크'</div>, <div class="cjs_t">웃음소리도 잠시 몇초만에 '불길'... 네팔 여객기 추락 직전 영상보니 [영상]</div>, <div class="cjs_t">장제원 아들 노엘 "전두환 시대‥나 건드리면 바로 지하실"</div>, <div class="cjs_t">전세제도의 구조적 허점, 이러면 우리도 당할 수 있다</div>, <div class="cjs_t">“택배기사 승강기 사용료 내라” 황당 갑질에 뭇매 맞은 세종시 아파트</div>, <div class="cjs_t">IMF "경제 분열로 세계 GDP 7% 줄어들 것"</div>, <div class="cjs_t">김기현 "김장연대 철 지나…모든 후보 안고 가도록 노력"</div>, <div class="cjs_t">팅크웨어, BMW 업고 매출 늘렸지만 이익률은 1%대…왜?</div>, <div class="cjs_t">코로나 외산백신 값 5배 오르는데 국산 백신·치료제는 퇴출 수순</div>, <div class="cjs_t">Lawmaker’s son blasted for Chun Doo-hwan reference in rap</div>, <div class="cjs_t">“매일 분초전쟁… 15분 빨라져 숨통” [새벽을 여는 사람들 싣고 8146번 버스는 달린다]</div>, <div class="cjs_t">'출마 고심' 나경원, 박정희 묘역 찾아… "정통 보수는 바로 나"</div>, <div class="cjs_t">부산 집값 지난해 4.59% 하락… 통계 이래 최대 기록</div>, <div class="cjs_t">세종 '하락 1위'…12월 집값 외환위기 후 최대로 '뚝뚝'</div>, <div class="cjs_t">배우 박진희, 기후위기 1인 시위 "엄마로서 끔찍하다"</div>, <div class="cjs_t">김건희 여사, UAE의 `국모` 파티마 여사와 환담…"여성 인권향상 활동 존경"</div>, <div class="cjs_t">절반이 ‘깡통 전세’… 화곡동 세입자 공포 커진다</div>, <div class="cjs_t">노엘 “나 건들면 바로 지하실”… 진중권 “아빠가 대통령이라는 것”</div>, <div class="cjs_t">"전세사기도 서러운데"…보일러도 안되는 임시거처엔 곰팡이투성이</div>, <div class="cjs_t">[자막뉴스] 봄인가 했는데 기온 10℃ 이상 뚝.. 다시 찾아온 겨울</div>, <div class="cjs_t">이자부담 숨통?…주담대 변동금리 낮아진다</div>, <div class="cjs_t">유승민의 운명, 나경원이 쥐었다?</div>, <div class="cjs_t">다보스포럼 개막...이재용·최태원 등 총출동</div>, <div class="cjs_t">[영상] "나는 동물 좋아하니까" UAE 아크부대에서 뜻밖의 동물사랑 보여준 김건희 여사</div>, <div class="cjs_t">[단독] '이태원 참사' 특수본, 한덕수 국무총리도 불송치</div>, <div class="cjs_t">성균관 "힘들게 전 부치지 않아도 돼"…차례 간소화 거듭 권고</div>, <div class="cjs_t">‘추위 적응 훈련’하다가 숨진 이등병…사망 원인은?</div>, <div class="cjs_t">한동훈 "이재명, 힘자랑 뒤 숨을 단계 지나"</div>, <div class="cjs_t">매장 한복판서 “뒤엎고 드러눕고”…‘고객 갑질’에 멍드는 백화점</div>, <div class="cjs_t">野, 김건희 군복 착용에 “대통령 노릇” 비판…알고 보니 김정숙은 여러번 입어</div>, <div class="cjs_t">SK가 자발적 탄소감축 시장에 주목한 이유</div>, <div class="cjs_t">'순식간에 아수라장' 네팔 항공기 추락 직전 영상 공개</div>, <div class="cjs_t">[밀당365] 당뇨병성 신증 치료제 나오나? ‘아이수지낙시브’의 효과</div>, <div class="cjs_t">K-드라마 여주가 달라졌다, 더 강하고 다채롭게</div>, <div class="cjs_t">비극으로 들어선 부동산, 슬픈 예감은 틀리지 않는다</div>, <div  ...

# %%
result = []
for element in dom.select(".cjs_news_tw .cjs_t"):
    result.append(element.text.strip())
print(result)
# Out:
# ['기체 90도 기울며 추락…네팔 민항기 마지막 순간(영상)', '한동훈, \'이재명 만난 적 없다\' 김성태에 "일종의 말맞추기 신호...그런다고 범죄 수사가 안 되지 않아"', '[거칠부 다이어리] 안나푸르나에서 닭 백숙을 삶다', "'한파도 좋아' 제철 맞은 가평 어비계곡 빙벽 [포토뉴스]", "또 이 가방 들었네…김건희 여사 '19만원 친환경 백'", '"기준 강화해 층간소음 잡겠다?" 탁상공론과 뼈아픈 현실', "한국일보 '김만배 돈거래' 간부 해고", '“월 60만원에 주말·야근 풀근무?” 얘 때문에 알바 자리 뺏겼다', '검찰, 이재명에 또 소환 통보…이번엔 ‘대장동 개발 특혜’ 의혹', '[단독] \'또 다른 징용 현장\' 사도광산 명부 입수…"조선인 사망자 9명"', '"지금 주문하면 3월에나"…김건희 여사 또 들자 \'품절 대란\'', '9·19 합의 정지하면 대북확성기 켜도 돼?', '박지원 “尹, 모두가 차렷 할 때 나홀로 UAE 국기에 경례..왜 그런지 몰라”[여의도초대석]', "점수도 명단도 비공개… TBS 차기대표 후보 추천도 '암흑심사'", '강남 음식점 여사장 ‘알몸시위’ 왜…"건물주 고발합니다"', '中 ‘일대일로’로 지은 네팔 공항서 추락 사고…부실 공사 의혹도', "[영상] 기내 흔들리더니 순식간에 '쾅'…네팔 항공기 추락 순간", '"네팔 경찰, 추락 여객기 사망자 중 한국인 1명 신원 확인"', '은행 희망퇴직은 ‘돈 잔치’… 노조도 대상 확대 요구', '캠핑 인구 700만 시대, 커져 가는 RV 시장', 'Korean victims in Nepal crash were father and son', '윤 대통령, 또 타국 국가 연주때 홀로 가슴 손[어텐션 뉴스]', '"외유성 연수에 배우자 참여".. 지역 농협 조합장 고발', "이상민에게 '이태원 참사'와  '2차 가해'의 책임을 물었다", '"한국 청소년들 소름 돋는다"…K드라마 학폭에 세계가 놀랐다', '‘비밀번호 변경’ 긴급 메일⋯알고 보니 북한발 해킹시도', '5대 은행 평균연봉 1억?…"예대마진 폭리, 횡재세 부과해라" 네티즌 냉소 [e라이프]', '[심층] 학원가 재수행렬 이어져', '동탄 집값 5억~6억씩 ‘뚝뚝’…신규 분양에 선착순 계약 등장', '국내 최초 美 FDA 승인 획득, 한국 제약산업 선도한 종근당', "'개코'가 건강? ... 후각은 '노화'의 지표", '"애플워치 기능 확대" 규제샌드박스\'노크\'', "웃음소리도 잠시 몇초만에 '불길'... 네팔 여객기 추락 직전 영상보니 [영상]", '장제원 아들 노엘 "전두환 시대‥나 건드리면 바로 지하실"', '전세제도의 구조적 허점, 이러면 우리도 당할 수 있다', '“택배기사 승강기 사용료 내라” 황당 갑질에 뭇매 맞은 세종시 아파트', 'IMF "경제 분열로 세계 GDP 7% 줄어들 것"', '김기현 "김장연대 철 지나…모든 후보 안고 가도록 노력"', '팅크웨어, BMW 업고 매출 늘렸지만 이익률은 1%대…왜?', '코로나 외산백신 값 5배 오르는데 국산 백신·치료제는 퇴출 수순', 'Lawmaker’s son blasted for Chun Doo-hwan reference in rap', '“매일 분초전쟁… 15분 빨라져 숨통” [새벽을 여는 사람들 싣고 8146번 버스는 달린다]', '\'출마 고심\' 나경원, 박정희 묘역 찾아… "정통 보수는 바로 나"', '부산 집값 지난해 4.59% 하락… 통계 이래 최대 기록', "세종 '하락 1위'…12월 집값 외환위기 후 최대로 '뚝뚝'", '배우 박진희, 기후위기 1인 시위 "엄마로서 끔찍하다"', '김건희 여사, UAE의 `국모` 파티마 여사와 환담…"여성 인권향상 활동 존경"', '절반이 ‘깡통 전세’… 화곡동 세입자 공포 커진다', '노엘 “나 건들면 바로 지하실”… 진중권 “아빠가 대통령이라는 것”', '"전세사기도 서러운데"…보일러도 안되는 임시거처엔 곰팡이투성이', '[자막뉴스] 봄인가 했는데 기온 10℃ 이상 뚝.. 다시 찾아온 겨울', '이자부담 숨통?…주담대 변동금리 낮아진다', '유승민의 운명, 나경원이 쥐었다?', '다보스포럼 개막...이재용·최태원 등 총출동', '[영상] "나는 동물 좋아하니까" UAE 아크부대에서 뜻밖의 동물사랑 보여준 김건희 여사', "[단독] '이태원 참사' 특수본, 한덕수 국무총리도 불송치", '성균관 "힘들게 전 부치지 않아도 돼"…차례 간소화 거듭 권고', '‘추위 적응 훈련’하다가 숨진 이등병…사망 원인은?', '한동훈 "이재명, 힘자랑 뒤 숨을 단계 지나"', '매장 한복판서 “뒤엎고 드러눕고”…‘고객 갑질’에 멍드는 백화점', '野, 김건희 군복 착용에 “대통령 노릇” 비판…알고 보니 김정숙은 여러번 입어', 'SK가 자발적 탄소감축 시장에 주목한 이유', "'순식간에 아수라장' 네팔 항공기 추락 직전 영상 공개", '[밀당365] 당뇨병성 신증 치료제 나오나? ‘아이수지낙시브’의 효과', 'K-드라마 여주가 달라졌다, 더 강하고 다채롭게', '비극으로 들어선 부동산, 슬픈 예감은 틀리지 않는다', '설 연휴 전 실내마스크 벗기 어려울 듯..."해외 요인 때문"', '500억 대출 연장 무산...엘시티 워터파크 공매 위기', "교대 1차 합격한 '수능 9등급'...초등교사 인기는 옛말?", "'세계 최초' 3차원 가상 공간서 등본 떼고 세무 상담 받는다", '손준성 재판에서 드러난 의혹, 검찰의 ‘김웅 봐주기’ 꼬리 잡히나', '성균관 “설 차례상 정해진 과일없어… 자유롭게 올려도 된다”', '일본 기업, 강제동원 피해 배상 요구에 "이미 해결"', '"韓 기업 맞아?"…中 눈치 보는 삼성, 올해도 \'중국 설\' 표기 논란', '6·25전사자 신원 미확인 13만 명… 유가족 찾기 본격화', "尹대통령, '지하벙커 위치 노출' 군사기밀누설 '무혐의'", '공유플랫폼서 차 빌렸다…‘사망 사고’ 공주 무면허 10대 동승자도 입건', '정기석 "실내마스크 해제 시기 설 전후에는 정할 것"', '팬데믹 속에서 ‘사회적 가족’ 인정 필요성 커졌다', '논란의 축의금액수…“10만원 못하면 5만원하고 ‘노쇼’”', '내일 아침 기온 오늘보다 5도 더 떨어진다..."설 연휴까지 추워요"', '이은해 울먹이자… 친척 오빠 “악마라는 표현은 좀”']

# %% [markdown]
# ## 완성 코드

# %%
import requests
from bs4 import BeautifulSoup
url = "https://news.naver.com/"
response = requests.get(url)
if response.status_code == 200:
    dom = BeautifulSoup(response.text, "html.parser")
    result = []
    for element in dom.select(".cjs_news_tw .cjs_t"):
        result.append(element.text.strip())
    print(result)
# Out:
# ['성균관 “설 차례상 정해진 과일없어… 자유롭게 올려도 된다”', "'한파도 좋아' 제철 맞은 가평 어비계곡 빙벽 [포토뉴스]", '코로나 외산백신 값 5배 오르는데 국산 백신·치료제는 퇴출 수순', '[심층] 학원가 재수행렬 이어져', "이상민에게 '이태원 참사'와  '2차 가해'의 책임을 물었다", "세종 '하락 1위'…12월 집값 외환위기 후 최대로 '뚝뚝'", '유승민의 운명, 나경원이 쥐었다?', '尹 일정 ‘밀착 동행’…김건희 여사의 달라진 행보', '野, 김건희 군복 착용에 “대통령 노릇” 비판…알고 보니 김정숙은 여러번 입어', '“월 60만원에 주말·야근 풀근무?” 얘 때문에 알바 자리 뺏겼다', '中 ‘일대일로’로 지은 네팔 공항서 추락 사고…부실 공사 의혹도', '설 연휴 전 실내마스크 벗기 어려울 듯..."해외 요인 때문"', 'Lawmaker’s son blasted for Chun Doo-hwan reference in rap', '기체 90도 기울며 추락…네팔 민항기 마지막 순간(영상)', '김건희 여사에 “누가 대통령인지 모르겠다”는 김남국', '일본 기업, 강제동원 피해 배상 요구에 "이미 해결"', "'개코'가 건강? ... 후각은 '노화'의 지표", 'K-드라마 여주가 달라졌다, 더 강하고 다채롭게', '은행 희망퇴직은 ‘돈 잔치’… 노조도 대상 확대 요구', '‘비밀번호 변경’ 긴급 메일⋯알고 보니 북한발 해킹시도', '‘성남FC 의혹’ 조사받은 이재명… 이번엔 ‘대장동 의혹’ 소환 통보', '캠핑 인구 700만 시대, 커져 가는 RV 시장', "점수도 명단도 비공개… TBS 차기대표 후보 추천도 '암흑심사'", '500억 대출 연장 무산...엘시티 워터파크 공매 위기', "'대장동·위례 의혹' 이재명 출석 통보…수사 1년4개월 만에", '윤 대통령, 또 타국 국가 연주때 홀로 가슴 손[어텐션 뉴스]', '[거칠부 다이어리] 안나푸르나에서 닭 백숙을 삶다', '이은해 울먹이자… 친척 오빠 “악마라는 표현은 좀”', '네팔여객기 사고직전 동영상 공개..."계산착오로 실속 가능성"', '팬데믹 속에서 ‘사회적 가족’ 인정 필요성 커졌다', '네팔 추락 항공기, 데이터·대화기록기 찾아…생존자는 없어', '[뉴스7] 네팔 여객기 추락 한국인 1명 신원 확인…안타까운 사연 이어져', '배우 박진희, 기후위기 1인 시위 "엄마로서 끔찍하다"', '다보스포럼 개막...이재용·최태원 등 총출동', '장제원 아들 노엘 "전두환 시대‥나 건드리면 바로 지하실"', '한동훈, \'이재명 만난 적 없다\' 김성태에 "일종의 말맞추기 신호...그런다고 범죄 수사가 안 되지 않아"', 'Korean victims in Nepal crash were father and son', '[영상] "나는 동물 좋아하니까" UAE 아크부대에서 뜻밖의 동물사랑 보여준 김건희 여사', "[영상] 기내 흔들리더니 순식간에 '쾅'…네팔 항공기 추락 순간", '"네팔 경찰, 추락 여객기 사망자 중 한국인 1명 신원 확인"', '"한국 청소년들 소름 돋는다"…K드라마 학폭에 세계가 놀랐다', '전세제도의 구조적 허점, 이러면 우리도 당할 수 있다', '국방부 지하벙커 위치 짚은 尹 대통령, ‘군사기밀 누설’ 무혐의로 종결', '절반이 ‘깡통 전세’… 화곡동 세입자 공포 커진다', '이자부담 숨통?…주담대 변동금리 낮아진다', '부산 집값 지난해 4.59% 하락… 통계 이래 최대 기록', '팅크웨어, BMW 업고 매출 늘렸지만 이익률은 1%대…왜?', '[단독] \'또 다른 징용 현장\' 사도광산 명부 입수…"조선인 사망자 9명"', "교대 1차 합격한 '수능 9등급'...초등교사 인기는 옛말?", '자중지란으로 지리멸렬한 여당에 정권교체 일등공신인 대구경북 시도민 한 숨', '"지금 주문하면 3월에나"…김건희 여사 또 들자 \'품절 대란\'', '새벽 3시50분 첫차, 일하는 이들의 소중한 ‘15분’ 싣고 달린다', '9·19 합의 정지하면 대북확성기 켜도 돼?', '정기석 "실내마스크 해제 시기 설 전후에는 정할 것"', '"층간소음 때문에" 음식물 투척에 방화까지', "'순식간에 아수라장' 네팔 항공기 추락 직전 영상 공개", '국내 최초 美 FDA 승인 획득, 한국 제약산업 선도한 종근당', "한국일보 '김만배 돈거래' 간부 해고", '동탄 집값 5억~6억씩 ‘뚝뚝’…신규 분양에 선착순 계약 등장', '5대 은행 평균연봉 1억?…"예대마진 폭리, 횡재세 부과해라" 네티즌 냉소 [e라이프]', '"전세사기도 서러운데"…보일러도 안되는 임시거처엔 곰팡이투성이', 'IMF "경제 분열로 세계 GDP 7% 줄어들 것"', "웃음소리도 잠시 몇초만에 '불길'... 네팔 여객기 추락 직전 영상보니 [영상]", "또 이 가방 들었네…김건희 여사 '19만원 친환경 백'", '손준성 재판에서 드러난 의혹, 검찰의 ‘김웅 봐주기’ 꼬리 잡히나', '\'출마 고심\' 나경원, 박정희 묘역 찾아… "정통 보수는 바로 나"', '내일 아침 기온 오늘보다 5도 더 떨어진다..."설 연휴까지 추워요"', '김건희 여사, UAE의 `국모` 파티마 여사와 환담…"여성 인권향상 활동 존경"', '[자막뉴스] 봄인가 했는데 기온 10℃ 이상 뚝.. 다시 찾아온 겨울', '김기현 "김장연대 철 지나…모든 후보 안고 가도록 노력"', '"애플워치 기능 확대" 규제샌드박스\'노크\'', '[밀당365] 당뇨병성 신증 치료제 나오나? ‘아이수지낙시브’의 효과', '매장 한복판서 “뒤엎고 드러눕고”…‘고객 갑질’에 멍드는 백화점', '대통령 “UAE의 적은 이란, 우리 적은 북한” 발언 적절했나?', '강남 음식점 여사장 ‘알몸시위’ 왜…"건물주 고발합니다"', 'SK가 자발적 탄소감축 시장에 주목한 이유', '"기준 강화해 층간소음 잡겠다?" 탁상공론과 뼈아픈 현실', '박지원 “尹, 모두가 차렷 할 때 나홀로 UAE 국기에 경례..왜 그런지 몰라”[여의도초대석]', '"외유성 연수에 배우자 참여".. 지역 농협 조합장 고발', '비극으로 들어선 부동산, 슬픈 예감은 틀리지 않는다', '논란의 축의금액수…“10만원 못하면 5만원하고 ‘노쇼’”', '“택배기사 승강기 사용료 내라” 황당 갑질에 뭇매 맞은 세종시 아파트']
